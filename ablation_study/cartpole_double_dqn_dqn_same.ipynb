# %% [markdown]
# Experiment IDs to indicate which environment to run
# 1. ID 1 = CartPole-v1    + DQN
# 2. ID 2 = CartPole-v1    + Double DQN
# 3. ID 3 = LunarLander-v3 + DQN
# 4. ID 4 = LunarLander-v3 + Double DQN

# %% [markdown]
# ## Imports

# %%
import copy
import random
from collections import deque

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Reproducibility and Device Setting

# %%
SEED = 42


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


set_seed(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SAVE_MODEL = True
SAVE_RESULTS = True
SHOW_PLOTS = True

# %% [markdown]
# ## Hyperparameters

# %%
EXPERIMENTS = {
    1: {
        "environment": "CartPole-v1",
        "algorithm": "DQN",
        "config": {
            "episodes": 2000,
            "learning_rate": 0.00005,
            "gamma": 0.99,
            "batch_size": 64,
            "replay_buffer_size": 50000,
            "minimum_replay_size": 1000,
            "target_update_frequency": 1000,
            "train_frequency": 1,
            "epsilon_start": 1.0,
            "epsilon_end": 0.02,
            "epsilon_decay_steps": 15000,
            "hidden_layers": [128, 128],
            "gradient_clip": 10.0,
            "evaluation_episodes": 20,
            "success_reward": 475,
        },
    },
    2: {
        "environment": "CartPole-v1",
        "algorithm": "DoubleDQN",
        "config": {
            "episodes": 2000,
            "learning_rate": 0.00005,
            "gamma": 0.99,
            "batch_size": 64,
            "replay_buffer_size": 50000,
            "minimum_replay_size": 1000,
            "target_update_frequency": 1000,
            "train_frequency": 1,
            "epsilon_start": 1.0,
            "epsilon_end": 0.02,
            "epsilon_decay_steps": 15000,
            "hidden_layers": [128, 128],
            "gradient_clip": 10.0,
            "evaluation_episodes": 20,
            "success_reward": 475,
        },
    },
    3: {
        "environment": "LunarLander-v3",
        "algorithm": "DQN",
        "config": {
            "episodes": 3000,
            "learning_rate": 0.0005,
            "gamma": 0.99,
            "batch_size": 64,
            "replay_buffer_size": 100000,
            "minimum_replay_size": 2000,
            "target_update_frequency": 1000,
            "train_frequency": 1,
            "epsilon_start": 1.0,
            "epsilon_end": 0.01,
            "epsilon_decay_steps": 150000,
            "hidden_layers": [256, 256],
            "gradient_clip": 10.0,
            "evaluation_episodes": 50,
            "success_reward": 200
        },
    },
    4: {
        "environment": "LunarLander-v3",
        "algorithm": "DoubleDQN",
        "config": {
            "episodes": 3000,
            "learning_rate": 0.0005,
            "gamma": 0.99,
            "batch_size": 64,
            "replay_buffer_size": 100000,
            "minimum_replay_size": 2000,
            "target_update_frequency": 1000,
            "train_frequency": 1,
            "epsilon_start": 1.0,
            "epsilon_end": 0.01,
            "epsilon_decay_steps": 150000,
            "hidden_layers": [256, 256],
            "gradient_clip": 10.0,
            "evaluation_episodes": 50,
            "success_reward": 200,
        },
    },
}

# %% [markdown]
# ## Create and Validate Environment

# %%
def create_environment(environment_name, render_mode=None):
    if render_mode is None:
        return gym.make(environment_name)
    return gym.make(environment_name, render_mode=render_mode)


def validate_environment(env):
    if not isinstance(env.action_space, gym.spaces.Discrete):
        raise ValueError("DQN and Double DQN require a discrete action space.")
    if not isinstance(env.observation_space, gym.spaces.Box):
        raise ValueError("This implementation requires a Box observation space.")
    state_size = int(np.prod(env.observation_space.shape))
    action_size = env.action_space.n
    return state_size, action_size

# %% [markdown]
# ## Replay Buffer

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, state, action, reward, next_state, terminated, truncated):
        self.buffer.append((state, action, reward, next_state, terminated, truncated))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states = np.asarray([x[0] for x in batch], dtype=np.float32)
        actions = np.asarray([x[1] for x in batch], dtype=np.int64)
        rewards = np.asarray([x[2] for x in batch], dtype=np.float32)
        next_states = np.asarray([x[3] for x in batch], dtype=np.float32)
        terminated = np.asarray([x[4] for x in batch], dtype=np.float32)
        truncated = np.asarray([x[5] for x in batch], dtype=np.float32)
        return (states, actions, rewards, next_states, terminated, truncated)

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# ## DQN and Double-DQN Related Definitions

# %%
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, hidden_layers):
        super().__init__()
        layers = []
        input_size = state_size
        for hidden_size in hidden_layers:
            layers.append(nn.Linear(input_size, hidden_size))
            layers.append(nn.ReLU())
            input_size = hidden_size

        layers.append(nn.Linear(input_size, action_size))
        self.network = nn.Sequential(*layers)

    def forward(self, state):
        return self.network(state)


# Common components shared by DQN and Double DQN.
class BaseDQNAgent:
    def __init__(self, state_size, action_size, config):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = config["gamma"]
        self.batch_size = config["batch_size"]
        self.learning_rate = config["learning_rate"]
        self.minimum_replay_size = config["minimum_replay_size"]
        self.target_update_frequency = config["target_update_frequency"]
        self.train_frequency = config["train_frequency"]
        self.epsilon_start = config["epsilon_start"]
        self.epsilon_end = config["epsilon_end"]
        self.epsilon_decay_steps = config["epsilon_decay_steps"]
        self.gradient_clip = config["gradient_clip"]

        # online network
        self.online_network = QNetwork(
            state_size, action_size, config["hidden_layers"]
        ).to(DEVICE)

        # target network
        self.target_network = QNetwork(
            state_size, action_size, config["hidden_layers"]
        ).to(DEVICE)

        # initially target = online
        self.target_network.load_state_dict(self.online_network.state_dict())
        self.target_network.eval()

        self.optimizer = optim.Adam(
            self.online_network.parameters(), lr=self.learning_rate
        )
        self.loss_function = nn.SmoothL1Loss()

        self.replay_buffer = ReplayBuffer(config["replay_buffer_size"])
        self.total_steps = 0
        self.training_steps = 0

    def get_epsilon(self):
        progress = min(self.total_steps / self.epsilon_decay_steps, 1.0)
        return self.epsilon_start + progress * (self.epsilon_end - self.epsilon_start)

    def select_action(self, state, training=True):
        if training:
            epsilon = self.get_epsilon()
            if random.random() < epsilon:
                return random.randrange(self.action_size)
        state_tensor = torch.as_tensor(
            state, dtype=torch.float32, device=DEVICE
        ).unsqueeze(0)
        with torch.no_grad():
            q_values = self.online_network(state_tensor)
        return torch.argmax(q_values, dim=1).item()

    def store_transition(
        self, state, action, reward, next_state, terminated, truncated
    ):
        self.replay_buffer.add(state, action, reward, next_state, terminated, truncated)

    def calculate_current_q(self, states, actions):
        q_values = self.online_network(states)
        return q_values.gather(1, actions).squeeze(1)

    def calculate_target_q(self, rewards, next_states, terminated):
        raise NotImplementedError

    def train_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return None
        states, actions, rewards, next_states, terminated, truncated = (
            self.replay_buffer.sample(self.batch_size)
        )
        states = torch.as_tensor(states, dtype=torch.float32, device=DEVICE)
        actions = torch.as_tensor(actions, dtype=torch.long, device=DEVICE).unsqueeze(1)
        rewards = torch.as_tensor(rewards, dtype=torch.float32, device=DEVICE)
        next_states = torch.as_tensor(next_states, dtype=torch.float32, device=DEVICE)
        terminated = torch.as_tensor(terminated, dtype=torch.float32, device=DEVICE)
        current_q = self.calculate_current_q(states, actions)
        target_q = self.calculate_target_q(rewards, next_states, terminated)
        loss = self.loss_function(current_q, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(
            self.online_network.parameters(), self.gradient_clip
        )
        self.optimizer.step()
        self.training_steps += 1
        if (
            self.training_steps
            % self.target_update_frequency
            == 0
        ):
            self.update_target_network()
        return loss.item()

    def update_target_network(self):
        self.target_network.load_state_dict(self.online_network.state_dict())

    def save_model(self, filename):
        torch.save(
            {
                "online_network": self.online_network.state_dict(),
                "target_network": self.target_network.state_dict(),
                "optimizer": self.optimizer.state_dict(),
                "total_steps": self.total_steps,
                "training_steps": self.training_steps,
            },
            filename,
        )


class DQNAgent(BaseDQNAgent):
    def calculate_target_q(self, rewards, next_states, terminated):
        with torch.no_grad():
            next_q_values = self.target_network(next_states)
            max_next_q = torch.max(next_q_values, dim=1).values
        target_q = rewards + self.gamma * max_next_q * (1.0 - terminated)
        return target_q


class DoubleDQNAgent(BaseDQNAgent):
    def calculate_target_q(self, rewards, next_states, terminated):
        with torch.no_grad():
            online_next_q_values = self.online_network(next_states)
            best_actions = torch.argmax(online_next_q_values, dim=1)
            target_next_q_values = self.target_network(next_states)
            selected_target_q = target_next_q_values.gather(
                1, best_actions.unsqueeze(1)
            ).squeeze(1)
        target_q = rewards + self.gamma * selected_target_q * (1.0 - terminated)
        return target_q


def create_agent(algorithm_name, state_size, action_size, config):
    if algorithm_name == "DQN":
        print("Creating STANDARD DQN agent...")
        return DQNAgent(state_size, action_size, config)
    elif algorithm_name == "DoubleDQN":
        print("Creating DOUBLE DQN agent...")
        return DoubleDQNAgent(state_size, action_size, config)
    else:
        raise ValueError("Algorithm must be DQN or DoubleDQN.")

# %% [markdown]
# ## Training Function

# %%
def train_agent(env, agent, config):
    rewards = []
    episode_lengths = []
    losses = []
    epsilons = []
    best_average_reward = -float("inf")
    best_online_state = None
    best_target_state = None

    for episode in range(1, config["episodes"] + 1):
        state, info = env.reset(seed=SEED + episode)
        state = np.asarray(state, dtype=np.float32).flatten()
        episode_reward = 0.0
        episode_length = 0
        episode_losses = []

        while True:
            action = agent.select_action(state, training=True)
            next_state, reward, terminated, truncated, info = env.step(action)
            next_state = np.asarray(next_state, dtype=np.float32).flatten()
            agent.store_transition(
                state, action, reward, next_state, terminated, truncated
            )

            if len(agent.replay_buffer) >= agent.minimum_replay_size:
                if (
                    agent.total_steps
                    % agent.train_frequency
                    == 0
                ):
                    loss = agent.train_step()
                    if loss is not None:
                        episode_losses.append(loss)

            state = next_state
            episode_reward += reward
            episode_length += 1
            agent.total_steps += 1

            if terminated or truncated:
                break

        rewards.append(episode_reward)
        episode_lengths.append(episode_length)

        if episode_losses:
            average_loss = np.mean(episode_losses)
        else:
            average_loss = np.nan

        losses.append(average_loss)
        epsilons.append(agent.get_epsilon())
        average_reward = np.mean(rewards[-100:])

        if len(rewards) >= 100 and average_reward > best_average_reward:
            best_average_reward = average_reward
            best_online_state = copy.deepcopy(agent.online_network.state_dict())
            best_target_state = copy.deepcopy(agent.target_network.state_dict())

        print(
            f"Episode {episode:4d} | "
            f"Reward {episode_reward:8.2f} | "
            f"Avg100 {average_reward:8.2f} | "
            f"Length {episode_length:4d} | "
            f"Epsilon {epsilons[-1]:.4f} | "
            f"Loss {average_loss:.6f}"
        )

    if best_online_state is not None:
        agent.online_network.load_state_dict(best_online_state)
        agent.target_network.load_state_dict(best_target_state)

    return {
        "rewards": rewards,
        "episode_lengths": episode_lengths,
        "losses": losses,
        "epsilons": epsilons,
        "best_average_reward": best_average_reward,
    }

# %% [markdown]
# ## Evaluation Function

# %%
def evaluate_agent(environment_name, agent, config):
    env = create_environment(environment_name)

    evaluation_rewards = []
    evaluation_lengths = []

    for episode in range(config["evaluation_episodes"]):
        state, info = env.reset(seed=SEED + 10000 + episode)
        state = np.asarray(state, dtype=np.float32).flatten()
        total_reward = 0.0
        steps = 0

        while True:
            action = agent.select_action(state, training=False)
            next_state, reward, terminated, truncated, info = env.step(action)
            next_state = np.asarray(next_state, dtype=np.float32).flatten()
            state = next_state
            total_reward += reward
            steps += 1
            if terminated or truncated:
                break

        evaluation_rewards.append(total_reward)
        evaluation_lengths.append(steps)
    env.close()

    average_reward = np.mean(evaluation_rewards)
    reward_std = np.std(evaluation_rewards)
    average_length = np.mean(evaluation_lengths)
    threshold = config["success_reward"]
    successful_episodes = sum(reward >= threshold for reward in evaluation_rewards)
    success_rate = (successful_episodes / len(evaluation_rewards)) * 100

    print()
    print("=" * 70)
    print("FINAL EVALUATION")
    print("=" * 70)

    print(f"Experiment ID : {EXPERIMENT_ID}")
    print(f"Environment   : {ENV_NAME}")
    print(f"Algorithm     : {ALGORITHM_NAME}")
    print(f"Average Reward: {average_reward:.2f}")
    print(f"Reward Std    : {reward_std:.2f}")
    print(f"Average Length: {average_length:.2f}")
    print(f"Success Rate  : {success_rate:.2f}%")

    print("=" * 70)

    return {
        "average_reward": average_reward,
        "reward_std": reward_std,
        "average_length": average_length,
        "success_rate": success_rate,
        "episode_rewards": evaluation_rewards,
    }

# %% [markdown]
# ## Moving Average Calculation Function

# %%
# used to decide the best model
def moving_average(values, window=100):
    values = np.asarray(values, dtype=np.float32)
    if len(values) < window:
        return values
    return np.convolve(values, np.ones(window) / window, mode="valid")

# %% [markdown]
# ## Plottings

# %%
# rewards
def plot_rewards(rewards):
    plt.figure(figsize=(12, 6))
    plt.plot(rewards, alpha=0.30, label="Episode Reward")
    if len(rewards) >= 100:
        average = moving_average(rewards, 100)
        plt.plot(range(99, len(rewards)), average, label="100-Episode Moving Average")
        
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title(f"{ENV_NAME} - {ALGORITHM_NAME} - Reward")
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

# loss
def plot_loss(losses):
    plt.figure(figsize=(12, 6))
    plt.plot(losses)
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.title(f"{ENV_NAME} - {ALGORITHM_NAME} - Training Loss")
    plt.grid()
    plt.tight_layout()
    plt.show()

# epsilon
def plot_epsilon(epsilons):
    plt.figure(figsize=(12, 6))
    plt.plot(epsilons)
    plt.xlabel("Episode")
    plt.ylabel("Epsilon")
    plt.title(f"{ENV_NAME} - {ALGORITHM_NAME} - Epsilon")
    plt.grid()
    plt.tight_layout()
    plt.show()

# episode length
def plot_episode_lengths(lengths):
    plt.figure(figsize=(12, 6))
    plt.plot(lengths, alpha=0.30, label="Episode Length")
    if len(lengths) >= 100:
        average = moving_average(lengths, 100)
        plt.plot(range(99, len(lengths)), average, label="100-Episode Moving Average")

    plt.xlabel("Episode")
    plt.ylabel("Episode Length")
    plt.title(f"{ENV_NAME} - {ALGORITHM_NAME} - Episode Length")
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Save Results and Model

# %%
def save_training_results(results):
    filename = f"experiment_{EXPERIMENT_ID}_results.npz"
    np.savez(
        filename,
        rewards=np.asarray(results["rewards"], dtype=np.float32),
        episode_lengths=np.asarray(results["episode_lengths"], dtype=np.int32),
        losses=np.asarray(results["losses"], dtype=np.float32),
        epsilons=np.asarray(results["epsilons"], dtype=np.float32),
        best_average_reward=np.asarray(
            results["best_average_reward"], dtype=np.float32
        ),
    )
    print(f"Results saved: {filename}")


def save_model(agent):
    safe_environment = ENV_NAME.replace("-", "_")
    filename = (
        f"experiment_{EXPERIMENT_ID}_" f"{safe_environment}_" f"{ALGORITHM_NAME}.pth"
    )
    agent.save_model(filename)
    print(f"Model saved: {filename}")

# %% [markdown]
# ## Show the Experiment Configurations

# %%
def print_configuration():
    print()
    print("=" * 70)
    print("MODULAR DQN / DOUBLE DQN PROJECT")
    print("=" * 70)
    print(f"Experiment ID : {EXPERIMENT_ID}")
    print(f"Environment   : {ENV_NAME}")
    print(f"Algorithm     : {ALGORITHM_NAME}")
    print(f"Device        : {DEVICE}")
    print(f"Episodes      : {CONFIG['episodes']}")
    print(f"Learning Rate : {CONFIG['learning_rate']}")
    print(f"Gamma         : {CONFIG['gamma']}")
    print(f"Batch Size    : {CONFIG['batch_size']}")
    print(f"Replay Buffer : {CONFIG['replay_buffer_size']}")
    print(f"Hidden Layers : {CONFIG['hidden_layers']}")
    print("=" * 70)

# %% [markdown]
# ## Experiment Run

# %%
def run_experiment(experiment_id):

    global EXPERIMENT_ID
    global ENV_NAME
    global ALGORITHM_NAME
    global CONFIG

    EXPERIMENT_ID = experiment_id

    if EXPERIMENT_ID not in EXPERIMENTS:
        raise ValueError("EXPERIMENT_ID must be from 1 to 4.")

    experiment = EXPERIMENTS[EXPERIMENT_ID]
    ENV_NAME = experiment["environment"]
    ALGORITHM_NAME = experiment["algorithm"]
    CONFIG = experiment["config"]

    print_configuration()
    env = create_environment(ENV_NAME)
    state_size, action_size = validate_environment(env)

    print(f"Observation Space : " f"{env.observation_space}")
    print(f"Action Space      : " f"{env.action_space}")
    print(f"State Size        : {state_size}")
    print(f"Number of Actions : {action_size}")
    print("=" * 70)

    # training
    agent = create_agent(
        algorithm_name=ALGORITHM_NAME,
        state_size=state_size,
        action_size=action_size,
        config=CONFIG,
    )

    results = train_agent(env=env, agent=agent, config=CONFIG)
    env.close()
    
    if SAVE_MODEL:
        save_model(agent)

    # evaluation
    evaluation = evaluate_agent(environment_name=ENV_NAME, agent=agent, config=CONFIG)

    if SAVE_RESULTS:
        save_training_results(results)

    # plotting
    if SHOW_PLOTS:
        plot_rewards(results["rewards"])
        plot_loss(results["losses"])
        plot_epsilon(results["epsilons"])
        plot_episode_lengths(results["episode_lengths"])

    # summary
    print()
    print("=" * 70)
    print("EXPERIMENT COMPLETE")
    print("=" * 70)
    print(f"Experiment ID  : {EXPERIMENT_ID}")
    print(f"Environment    : {ENV_NAME}")
    print(f"Algorithm      : {ALGORITHM_NAME}")
    print(f"Average Reward : " f"{evaluation['average_reward']:.2f}")
    print(f"Reward Std     : " f"{evaluation['reward_std']:.2f}")
    print(f"Average Length : " f"{evaluation['average_length']:.2f}")
    print(f"Success Rate   : " f"{evaluation['success_rate']:.2f}%")
    print(f"Best Train Avg : " f"{results['best_average_reward']:.2f}")
    print("=" * 70)

# %% [markdown]
# ## Cartpole Double-DQN

# %%
run_experiment(2)
# Out:
# ======================================================================
# MODULAR DQN / DOUBLE DQN PROJECT
# ======================================================================
# Experiment ID : 2
# Environment   : CartPole-v1
# Algorithm     : DoubleDQN
# Device        : cuda
# Episodes      : 2000
# Learning Rate : 5e-05
# Gamma         : 0.99
# Batch Size    : 64
# Replay Buffer : 50000
# Hidden Layers : [128, 128]
# ======================================================================
# Observation Space : Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Action Space      : Discrete(2)
# State Size        : 4
# Number of Actions : 2
# ======================================================================
# Creating DOUBLE DQN agent...
# Episode    1 | Reward    11.00 | Avg100    11.00 | Length   11 | Epsilon 0.9993 | Loss nan
# Episode    2 | Reward    18.00 | Avg100    14.50 | Length   18 | Epsilon 0.9981 | Loss nan
# Episode    3 | Reward    10.00 | Avg100    13.00 | Length   10 | Epsilon 0.9975 | Loss nan
# Episode    4 | Reward    15.00 | Avg100    13.50 | Length   15 | Epsilon 0.9965 | Loss nan
# Episode    5 | Reward    20.00 | Avg100    14.80 | Length   20 | Epsilon 0.9952 | Loss nan
# Episode    6 | Reward    21.00 | Avg100    15.83 | Length   21 | Epsilon 0.9938 | Loss nan
# Episode    7 | Reward    13.00 | Avg100    15.43 | Length   13 | Epsilon 0.9929 | Loss nan
# Episode    8 | Reward    36.00 | Avg100    18.00 | Length   36 | Epsilon 0.9906 | Loss nan
# Episode    9 | Reward    57.00 | Avg100    22.33 | Length   57 | Epsilon 0.9869 | Loss nan
# Episode   10 | Reward    24.00 | Avg100    22.50 | Length   24 | Epsilon 0.9853 | Loss nan
# Episode   11 | Reward    14.00 | Avg100    21.73 | Length   14 | Epsilon 0.9844 | Loss nan
# Episode   12 | Reward    14.00 | Avg100    21.08 | Length   14 | Epsilon 0.9835 | Loss nan
# Episode   13 | Reward    21.00 | Avg100    21.08 | Length   21 | Epsilon 0.9821 | Loss nan
# Episode   14 | Reward    30.00 | Avg100    21.71 | Length   30 | Epsilon 0.9801 | Loss nan
# Episode   15 | Reward    63.00 | Avg100    24.47 | Length   63 | Epsilon 0.9760 | Loss nan
# Episode   16 | Reward    15.00 | Avg100    23.88 | Length   15 | Epsilon 0.9750 | Loss nan
# Episode   17 | Reward    23.00 | Avg100    23.82 | Length   23 | Epsilon 0.9735 | Loss nan
# Episode   18 | Reward    10.00 | Avg100    23.06 | Length   10 | Epsilon 0.9729 | Loss nan
# Episode   19 | Reward    54.00 | Avg100    24.68 | Length   54 | Epsilon 0.9694 | Loss nan
# Episode   20 | Reward    13.00 | Avg100    24.10 | Length   13 | Epsilon 0.9685 | Loss nan
# Episode   21 | Reward    17.00 | Avg100    23.76 | Length   17 | Epsilon 0.9674 | Loss nan
# Episode   22 | Reward    10.00 | Avg100    23.14 | Length   10 | Epsilon 0.9667 | Loss nan
# Episode   23 | Reward    14.00 | Avg100    22.74 | Length   14 | Epsilon 0.9658 | Loss nan
# Episode   24 | Reward    33.00 | Avg100    23.17 | Length   33 | Epsilon 0.9637 | Loss nan
# Episode   25 | Reward    20.00 | Avg100    23.04 | Length   20 | Epsilon 0.9624 | Loss nan
# Episode   26 | Reward    25.00 | Avg100    23.12 | Length   25 | Epsilon 0.9607 | Loss nan
# Episode   27 | Reward    13.00 | Avg100    22.74 | Length   13 | Epsilon 0.9599 | Loss nan
# Episode   28 | Reward    18.00 | Avg100    22.57 | Length   18 | Epsilon 0.9587 | Loss nan
# Episode   29 | Reward    20.00 | Avg100    22.48 | Length   20 | Epsilon 0.9574 | Loss nan
# Episode   30 | Reward    24.00 | Avg100    22.53 | Length   24 | Epsilon 0.9558 | Loss nan
# Episode   31 | Reward    31.00 | Avg100    22.81 | Length   31 | Epsilon 0.9538 | Loss nan
# Episode   32 | Reward    14.00 | Avg100    22.53 | Length   14 | Epsilon 0.9529 | Loss nan
# Episode   33 | Reward    23.00 | Avg100    22.55 | Length   23 | Epsilon 0.9514 | Loss nan
# Episode   34 | Reward    12.00 | Avg100    22.24 | Length   12 | Epsilon 0.9506 | Loss nan
# Episode   35 | Reward    19.00 | Avg100    22.14 | Length   19 | Epsilon 0.9494 | Loss nan
# Episode   36 | Reward    24.00 | Avg100    22.19 | Length   24 | Epsilon 0.9478 | Loss nan
# Episode   37 | Reward    60.00 | Avg100    23.22 | Length   60 | Epsilon 0.9439 | Loss nan
# Episode   38 | Reward    15.00 | Avg100    23.00 | Length   15 | Epsilon 0.9429 | Loss nan
# Episode   39 | Reward    13.00 | Avg100    22.74 | Length   13 | Epsilon 0.9420 | Loss nan
# Episode   40 | Reward    68.00 | Avg100    23.88 | Length   68 | Epsilon 0.9376 | Loss nan
# Episode   41 | Reward    21.00 | Avg100    23.80 | Length   21 | Epsilon 0.9362 | Loss nan
# Episode   42 | Reward    34.00 | Avg100    24.05 | Length   34 | Epsilon 0.9340 | Loss 0.496394
# Episode   43 | Reward    33.00 | Avg100    24.26 | Length   33 | Epsilon 0.9319 | Loss 0.446466
# Episode   44 | Reward    11.00 | Avg100    23.95 | Length   11 | Epsilon 0.9311 | Loss 0.398802
# Episode   45 | Reward    28.00 | Avg100    24.04 | Length   28 | Epsilon 0.9293 | Loss 0.358622
# Episode   46 | Reward    13.00 | Avg100    23.80 | Length   13 | Epsilon 0.9285 | Loss 0.315427
# Episode   47 | Reward    16.00 | Avg100    23.64 | Length   16 | Epsilon 0.9274 | Loss 0.288114
# Episode   48 | Reward    10.00 | Avg100    23.35 | Length   10 | Epsilon 0.9268 | Loss 0.261135
# Episode   49 | Reward    10.00 | Avg100    23.08 | Length   10 | Epsilon 0.9261 | Loss 0.247185
# Episode   50 | Reward    11.00 | Avg100    22.84 | Length   11 | Epsilon 0.9254 | Loss 0.224623
# Episode   51 | Reward    31.00 | Avg100    23.00 | Length   31 | Epsilon 0.9234 | Loss 0.192571
# Episode   52 | Reward    11.00 | Avg100    22.77 | Length   11 | Epsilon 0.9226 | Loss 0.151965
# Episode   53 | Reward    28.00 | Avg100    22.87 | Length   28 | Epsilon 0.9208 | Loss 0.125120
# Episode   54 | Reward    13.00 | Avg100    22.69 | Length   13 | Epsilon 0.9200 | Loss 0.101128
# Episode   55 | Reward    16.00 | Avg100    22.56 | Length   16 | Epsilon 0.9189 | Loss 0.084365
# Episode   56 | Reward    27.00 | Avg100    22.64 | Length   27 | Epsilon 0.9172 | Loss 0.067446
# Episode   57 | Reward    26.00 | Avg100    22.70 | Length   26 | Epsilon 0.9155 | Loss 0.050676
# Episode   58 | Reward    10.00 | Avg100    22.48 | Length   10 | Epsilon 0.9148 | Loss 0.040529
# Episode   59 | Reward    16.00 | Avg100    22.37 | Length   16 | Epsilon 0.9138 | Loss 0.035757
# Episode   60 | Reward    15.00 | Avg100    22.25 | Length   15 | Epsilon 0.9128 | Loss 0.031770
# Episode   61 | Reward    14.00 | Avg100    22.11 | Length   14 | Epsilon 0.9119 | Loss 0.028382
# Episode   62 | Reward    20.00 | Avg100    22.08 | Length   20 | Epsilon 0.9106 | Loss 0.024110
# Episode   63 | Reward    28.00 | Avg100    22.17 | Length   28 | Epsilon 0.9087 | Loss 0.020129
# Episode   64 | Reward    27.00 | Avg100    22.25 | Length   27 | Epsilon 0.9070 | Loss 0.017818
# Episode   65 | Reward    13.00 | Avg100    22.11 | Length   13 | Epsilon 0.9061 | Loss 0.014958
# Episode   66 | Reward    18.00 | Avg100    22.05 | Length   18 | Epsilon 0.9049 | Loss 0.012787
# Episode   67 | Reward    17.00 | Avg100    21.97 | Length   17 | Epsilon 0.9038 | Loss 0.012918
# Episode   68 | Reward    33.00 | Avg100    22.13 | Length   33 | Epsilon 0.9017 | Loss 0.011345
# Episode   69 | Reward    31.00 | Avg100    22.26 | Length   31 | Epsilon 0.8996 | Loss 0.009060
# Episode   70 | Reward    19.00 | Avg100    22.21 | Length   19 | Epsilon 0.8984 | Loss 0.008229
# Episode   71 | Reward    51.00 | Avg100    22.62 | Length   51 | Epsilon 0.8951 | Loss 0.006517
# Episode   72 | Reward    20.00 | Avg100    22.58 | Length   20 | Epsilon 0.8938 | Loss 0.004935
# Episode   73 | Reward    32.00 | Avg100    22.71 | Length   32 | Epsilon 0.8917 | Loss 0.003932
# Episode   74 | Reward    14.00 | Avg100    22.59 | Length   14 | Epsilon 0.8908 | Loss 0.003239
# Episode   75 | Reward    37.00 | Avg100    22.79 | Length   37 | Epsilon 0.8883 | Loss 0.003037
# Episode   76 | Reward    14.00 | Avg100    22.67 | Length   14 | Epsilon 0.8874 | Loss 0.002431
# Episode   77 | Reward    11.00 | Avg100    22.52 | Length   11 | Epsilon 0.8867 | Loss 0.002365
# Episode   78 | Reward    18.00 | Avg100    22.46 | Length   18 | Epsilon 0.8855 | Loss 0.002086
# Episode   79 | Reward    18.00 | Avg100    22.41 | Length   18 | Epsilon 0.8844 | Loss 0.001879
# Episode   80 | Reward    29.00 | Avg100    22.49 | Length   29 | Epsilon 0.8825 | Loss 0.001698
# Episode   81 | Reward    11.00 | Avg100    22.35 | Length   11 | Epsilon 0.8817 | Loss 0.001254
# Episode   82 | Reward    12.00 | Avg100    22.22 | Length   12 | Epsilon 0.8810 | Loss 0.001239
# Episode   83 | Reward    16.00 | Avg100    22.14 | Length   16 | Epsilon 0.8799 | Loss 0.001099
# Episode   84 | Reward    38.00 | Avg100    22.33 | Length   38 | Epsilon 0.8774 | Loss 0.001049
# Episode   85 | Reward    14.00 | Avg100    22.24 | Length   14 | Epsilon 0.8765 | Loss 0.000990
# Episode   86 | Reward    10.00 | Avg100    22.09 | Length   10 | Epsilon 0.8759 | Loss 0.000741
# Episode   87 | Reward    13.00 | Avg100    21.99 | Length   13 | Epsilon 0.8750 | Loss 0.000813
# Episode   88 | Reward    12.00 | Avg100    21.88 | Length   12 | Epsilon 0.8742 | Loss 0.000848
# Episode   89 | Reward    13.00 | Avg100    21.78 | Length   13 | Epsilon 0.8734 | Loss 0.000651
# Episode   90 | Reward    17.00 | Avg100    21.72 | Length   17 | Epsilon 0.8723 | Loss 0.000610
# Episode   91 | Reward    10.00 | Avg100    21.59 | Length   10 | Epsilon 0.8716 | Loss 0.000620
# Episode   92 | Reward    27.00 | Avg100    21.65 | Length   27 | Epsilon 0.8699 | Loss 0.000536
# Episode   93 | Reward    13.00 | Avg100    21.56 | Length   13 | Epsilon 0.8690 | Loss 0.215446
# Episode   94 | Reward    13.00 | Avg100    21.47 | Length   13 | Epsilon 0.8682 | Loss 0.349217
# Episode   95 | Reward     9.00 | Avg100    21.34 | Length    9 | Epsilon 0.8676 | Loss 0.224118
# Episode   96 | Reward    23.00 | Avg100    21.35 | Length   23 | Epsilon 0.8661 | Loss 0.116583
# Episode   97 | Reward    58.00 | Avg100    21.73 | Length   58 | Epsilon 0.8623 | Loss 0.050513
# Episode   98 | Reward    44.00 | Avg100    21.96 | Length   44 | Epsilon 0.8594 | Loss 0.032243
# Episode   99 | Reward    27.00 | Avg100    22.01 | Length   27 | Epsilon 0.8576 | Loss 0.038179
# Episode  100 | Reward    14.00 | Avg100    21.93 | Length   14 | Epsilon 0.8567 | Loss 0.020515
# Episode  101 | Reward    25.00 | Avg100    22.07 | Length   25 | Epsilon 0.8551 | Loss 0.025662
# Episode  102 | Reward    14.00 | Avg100    22.03 | Length   14 | Epsilon 0.8542 | Loss 0.021787
# Episode  103 | Reward    37.00 | Avg100    22.30 | Length   37 | Epsilon 0.8518 | Loss 0.021143
# Episode  104 | Reward    20.00 | Avg100    22.35 | Length   20 | Epsilon 0.8505 | Loss 0.017292
# Episode  105 | Reward    35.00 | Avg100    22.50 | Length   35 | Epsilon 0.8482 | Loss 0.018611
# Episode  106 | Reward    19.00 | Avg100    22.48 | Length   19 | Epsilon 0.8469 | Loss 0.021198
# Episode  107 | Reward    21.00 | Avg100    22.56 | Length   21 | Epsilon 0.8456 | Loss 0.022020
# Episode  108 | Reward    29.00 | Avg100    22.49 | Length   29 | Epsilon 0.8437 | Loss 0.022527
# Episode  109 | Reward    19.00 | Avg100    22.11 | Length   19 | Epsilon 0.8424 | Loss 0.017540
# Episode  110 | Reward    21.00 | Avg100    22.08 | Length   21 | Epsilon 0.8410 | Loss 0.018119
# Episode  111 | Reward    16.00 | Avg100    22.10 | Length   16 | Epsilon 0.8400 | Loss 0.015013
# Episode  112 | Reward    15.00 | Avg100    22.11 | Length   15 | Epsilon 0.8390 | Loss 0.017795
# Episode  113 | Reward    15.00 | Avg100    22.05 | Length   15 | Epsilon 0.8380 | Loss 0.017753
# Episode  114 | Reward    12.00 | Avg100    21.87 | Length   12 | Epsilon 0.8373 | Loss 0.018105
# Episode  115 | Reward    22.00 | Avg100    21.46 | Length   22 | Epsilon 0.8358 | Loss 0.017966
# Episode  116 | Reward    26.00 | Avg100    21.57 | Length   26 | Epsilon 0.8341 | Loss 0.020076
# Episode  117 | Reward    11.00 | Avg100    21.45 | Length   11 | Epsilon 0.8334 | Loss 0.013477
# Episode  118 | Reward    20.00 | Avg100    21.55 | Length   20 | Epsilon 0.8321 | Loss 0.020963
# Episode  119 | Reward    17.00 | Avg100    21.18 | Length   17 | Epsilon 0.8310 | Loss 0.016561
# Episode  120 | Reward    12.00 | Avg100    21.17 | Length   12 | Epsilon 0.8302 | Loss 0.017489
# Episode  121 | Reward    23.00 | Avg100    21.23 | Length   23 | Epsilon 0.8287 | Loss 0.015065
# Episode  122 | Reward    11.00 | Avg100    21.24 | Length   11 | Epsilon 0.8280 | Loss 0.013600
# Episode  123 | Reward    30.00 | Avg100    21.40 | Length   30 | Epsilon 0.8260 | Loss 0.016401
# Episode  124 | Reward    13.00 | Avg100    21.20 | Length   13 | Epsilon 0.8252 | Loss 0.018447
# Episode  125 | Reward    14.00 | Avg100    21.14 | Length   14 | Epsilon 0.8243 | Loss 0.017717
# Episode  126 | Reward    16.00 | Avg100    21.05 | Length   16 | Epsilon 0.8232 | Loss 0.011941
# Episode  127 | Reward    14.00 | Avg100    21.06 | Length   14 | Epsilon 0.8223 | Loss 0.017360
# Episode  128 | Reward    24.00 | Avg100    21.12 | Length   24 | Epsilon 0.8207 | Loss 0.017542
# Episode  129 | Reward    35.00 | Avg100    21.27 | Length   35 | Epsilon 0.8184 | Loss 0.014514
# Episode  130 | Reward    12.00 | Avg100    21.15 | Length   12 | Epsilon 0.8177 | Loss 0.012840
# Episode  131 | Reward    17.00 | Avg100    21.01 | Length   17 | Epsilon 0.8165 | Loss 0.017434
# Episode  132 | Reward    31.00 | Avg100    21.18 | Length   31 | Epsilon 0.8145 | Loss 0.017405
# Episode  133 | Reward    31.00 | Avg100    21.26 | Length   31 | Epsilon 0.8125 | Loss 0.015663
# Episode  134 | Reward    14.00 | Avg100    21.28 | Length   14 | Epsilon 0.8116 | Loss 0.013368
# Episode  135 | Reward    23.00 | Avg100    21.32 | Length   23 | Epsilon 0.8101 | Loss 0.015730
# Episode  136 | Reward    17.00 | Avg100    21.25 | Length   17 | Epsilon 0.8090 | Loss 0.016527
# Episode  137 | Reward    15.00 | Avg100    20.80 | Length   15 | Epsilon 0.8080 | Loss 0.015715
# Episode  138 | Reward    14.00 | Avg100    20.79 | Length   14 | Epsilon 0.8071 | Loss 0.019632
# Episode  139 | Reward    15.00 | Avg100    20.81 | Length   15 | Epsilon 0.8061 | Loss 0.018047
# Episode  140 | Reward    12.00 | Avg100    20.25 | Length   12 | Epsilon 0.8053 | Loss 0.014234
# Episode  141 | Reward    17.00 | Avg100    20.21 | Length   17 | Epsilon 0.8042 | Loss 0.015537
# Episode  142 | Reward    32.00 | Avg100    20.19 | Length   32 | Epsilon 0.8021 | Loss 0.254092
# Episode  143 | Reward    12.00 | Avg100    19.98 | Length   12 | Epsilon 0.8013 | Loss 0.084476
# Episode  144 | Reward    14.00 | Avg100    20.01 | Length   14 | Epsilon 0.8004 | Loss 0.072942
# Episode  145 | Reward    11.00 | Avg100    19.84 | Length   11 | Epsilon 0.7997 | Loss 0.070487
# Episode  146 | Reward    32.00 | Avg100    20.03 | Length   32 | Epsilon 0.7976 | Loss 0.060186
# Episode  147 | Reward    18.00 | Avg100    20.05 | Length   18 | Epsilon 0.7964 | Loss 0.065079
# Episode  148 | Reward    19.00 | Avg100    20.14 | Length   19 | Epsilon 0.7952 | Loss 0.056258
# Episode  149 | Reward    13.00 | Avg100    20.17 | Length   13 | Epsilon 0.7943 | Loss 0.058249
# Episode  150 | Reward    10.00 | Avg100    20.16 | Length   10 | Epsilon 0.7937 | Loss 0.050103
# Episode  151 | Reward    15.00 | Avg100    20.00 | Length   15 | Epsilon 0.7927 | Loss 0.057237
# Episode  152 | Reward    22.00 | Avg100    20.11 | Length   22 | Epsilon 0.7913 | Loss 0.053505
# Episode  153 | Reward    35.00 | Avg100    20.18 | Length   35 | Epsilon 0.7890 | Loss 0.035596
# Episode  154 | Reward    14.00 | Avg100    20.19 | Length   14 | Epsilon 0.7881 | Loss 0.044715
# Episode  155 | Reward    16.00 | Avg100    20.19 | Length   16 | Epsilon 0.7870 | Loss 0.049391
# Episode  156 | Reward    15.00 | Avg100    20.07 | Length   15 | Epsilon 0.7860 | Loss 0.047408
# Episode  157 | Reward    30.00 | Avg100    20.11 | Length   30 | Epsilon 0.7841 | Loss 0.046680
# Episode  158 | Reward    40.00 | Avg100    20.41 | Length   40 | Epsilon 0.7815 | Loss 0.042468
# Episode  159 | Reward    18.00 | Avg100    20.43 | Length   18 | Epsilon 0.7803 | Loss 0.050391
# Episode  160 | Reward    19.00 | Avg100    20.47 | Length   19 | Epsilon 0.7790 | Loss 0.037939
# Episode  161 | Reward    16.00 | Avg100    20.49 | Length   16 | Epsilon 0.7780 | Loss 0.045299
# Episode  162 | Reward    21.00 | Avg100    20.50 | Length   21 | Epsilon 0.7766 | Loss 0.046807
# Episode  163 | Reward    37.00 | Avg100    20.59 | Length   37 | Epsilon 0.7742 | Loss 0.050727
# Episode  164 | Reward    24.00 | Avg100    20.56 | Length   24 | Epsilon 0.7726 | Loss 0.038517
# Episode  165 | Reward    32.00 | Avg100    20.75 | Length   32 | Epsilon 0.7705 | Loss 0.051295
# Episode  166 | Reward    12.00 | Avg100    20.69 | Length   12 | Epsilon 0.7698 | Loss 0.044269
# Episode  167 | Reward    21.00 | Avg100    20.73 | Length   21 | Epsilon 0.7684 | Loss 0.043410
# Episode  168 | Reward    15.00 | Avg100    20.55 | Length   15 | Epsilon 0.7674 | Loss 0.032684
# Episode  169 | Reward    15.00 | Avg100    20.39 | Length   15 | Epsilon 0.7664 | Loss 0.028960
# Episode  170 | Reward    17.00 | Avg100    20.37 | Length   17 | Epsilon 0.7653 | Loss 0.038974
# Episode  171 | Reward    36.00 | Avg100    20.22 | Length   36 | Epsilon 0.7630 | Loss 0.047568
# Episode  172 | Reward    67.00 | Avg100    20.69 | Length   67 | Epsilon 0.7586 | Loss 0.044423
# Episode  173 | Reward    33.00 | Avg100    20.70 | Length   33 | Epsilon 0.7564 | Loss 0.054848
# Episode  174 | Reward    49.00 | Avg100    21.05 | Length   49 | Epsilon 0.7532 | Loss 0.049397
# Episode  175 | Reward    21.00 | Avg100    20.89 | Length   21 | Epsilon 0.7519 | Loss 0.057842
# Episode  176 | Reward    23.00 | Avg100    20.98 | Length   23 | Epsilon 0.7504 | Loss 0.046559
# Episode  177 | Reward    17.00 | Avg100    21.04 | Length   17 | Epsilon 0.7493 | Loss 0.049847
# Episode  178 | Reward    17.00 | Avg100    21.03 | Length   17 | Epsilon 0.7481 | Loss 0.045711
# Episode  179 | Reward    26.00 | Avg100    21.11 | Length   26 | Epsilon 0.7464 | Loss 0.041714
# Episode  180 | Reward    18.00 | Avg100    21.00 | Length   18 | Epsilon 0.7453 | Loss 0.048475
# Episode  181 | Reward    61.00 | Avg100    21.50 | Length   61 | Epsilon 0.7413 | Loss 0.045843
# Episode  182 | Reward    22.00 | Avg100    21.60 | Length   22 | Epsilon 0.7398 | Loss 0.045739
# Episode  183 | Reward    61.00 | Avg100    22.05 | Length   61 | Epsilon 0.7359 | Loss 0.158800
# Episode  184 | Reward    69.00 | Avg100    22.36 | Length   69 | Epsilon 0.7313 | Loss 0.086055
# Episode  185 | Reward    12.00 | Avg100    22.34 | Length   12 | Epsilon 0.7306 | Loss 0.062504
# Episode  186 | Reward    48.00 | Avg100    22.72 | Length   48 | Epsilon 0.7274 | Loss 0.076775
# Episode  187 | Reward    17.00 | Avg100    22.76 | Length   17 | Epsilon 0.7263 | Loss 0.079190
# Episode  188 | Reward    28.00 | Avg100    22.92 | Length   28 | Epsilon 0.7245 | Loss 0.073413
# Episode  189 | Reward    25.00 | Avg100    23.04 | Length   25 | Epsilon 0.7229 | Loss 0.057809
# Episode  190 | Reward    18.00 | Avg100    23.05 | Length   18 | Epsilon 0.7217 | Loss 0.083759
# Episode  191 | Reward    29.00 | Avg100    23.24 | Length   29 | Epsilon 0.7198 | Loss 0.089007
# Episode  192 | Reward    32.00 | Avg100    23.29 | Length   32 | Epsilon 0.7177 | Loss 0.058021
# Episode  193 | Reward    12.00 | Avg100    23.28 | Length   12 | Epsilon 0.7169 | Loss 0.063260
# Episode  194 | Reward    71.00 | Avg100    23.86 | Length   71 | Epsilon 0.7123 | Loss 0.075376
# Episode  195 | Reward    88.00 | Avg100    24.65 | Length   88 | Epsilon 0.7065 | Loss 0.072177
# Episode  196 | Reward    42.00 | Avg100    24.84 | Length   42 | Epsilon 0.7038 | Loss 0.073857
# Episode  197 | Reward    38.00 | Avg100    24.64 | Length   38 | Epsilon 0.7013 | Loss 0.075227
# Episode  198 | Reward    14.00 | Avg100    24.34 | Length   14 | Epsilon 0.7004 | Loss 0.066575
# Episode  199 | Reward    18.00 | Avg100    24.25 | Length   18 | Epsilon 0.6992 | Loss 0.066271
# Episode  200 | Reward    62.00 | Avg100    24.73 | Length   62 | Epsilon 0.6952 | Loss 0.069021
# Episode  201 | Reward    41.00 | Avg100    24.89 | Length   41 | Epsilon 0.6925 | Loss 0.064595
# Episode  202 | Reward    53.00 | Avg100    25.28 | Length   53 | Epsilon 0.6890 | Loss 0.075120
# Episode  203 | Reward   105.00 | Avg100    25.96 | Length  105 | Epsilon 0.6822 | Loss 0.061590
# Episode  204 | Reward    20.00 | Avg100    25.96 | Length   20 | Epsilon 0.6808 | Loss 0.065462
# Episode  205 | Reward    47.00 | Avg100    26.08 | Length   47 | Epsilon 0.6778 | Loss 0.062028
# Episode  206 | Reward    24.00 | Avg100    26.13 | Length   24 | Epsilon 0.6762 | Loss 0.064335
# Episode  207 | Reward    60.00 | Avg100    26.52 | Length   60 | Epsilon 0.6723 | Loss 0.146168
# Episode  208 | Reward    21.00 | Avg100    26.44 | Length   21 | Epsilon 0.6709 | Loss 0.141411
# Episode  209 | Reward    37.00 | Avg100    26.62 | Length   37 | Epsilon 0.6685 | Loss 0.094078
# Episode  210 | Reward   145.00 | Avg100    27.86 | Length  145 | Epsilon 0.6590 | Loss 0.097434
# Episode  211 | Reward    20.00 | Avg100    27.90 | Length   20 | Epsilon 0.6577 | Loss 0.094090
# Episode  212 | Reward    74.00 | Avg100    28.49 | Length   74 | Epsilon 0.6529 | Loss 0.092677
# Episode  213 | Reward    32.00 | Avg100    28.66 | Length   32 | Epsilon 0.6508 | Loss 0.102818
# Episode  214 | Reward    57.00 | Avg100    29.11 | Length   57 | Epsilon 0.6471 | Loss 0.088777
# Episode  215 | Reward    75.00 | Avg100    29.64 | Length   75 | Epsilon 0.6422 | Loss 0.094425
# Episode  216 | Reward    86.00 | Avg100    30.24 | Length   86 | Epsilon 0.6366 | Loss 0.089472
# Episode  217 | Reward    35.00 | Avg100    30.48 | Length   35 | Epsilon 0.6343 | Loss 0.099123
# Episode  218 | Reward    20.00 | Avg100    30.48 | Length   20 | Epsilon 0.6330 | Loss 0.087469
# Episode  219 | Reward    90.00 | Avg100    31.21 | Length   90 | Epsilon 0.6271 | Loss 0.089447
# Episode  220 | Reward    72.00 | Avg100    31.81 | Length   72 | Epsilon 0.6224 | Loss 0.089630
# Episode  221 | Reward    21.00 | Avg100    31.79 | Length   21 | Epsilon 0.6210 | Loss 0.088118
# Episode  222 | Reward    97.00 | Avg100    32.65 | Length   97 | Epsilon 0.6147 | Loss 0.079919
# Episode  223 | Reward    28.00 | Avg100    32.63 | Length   28 | Epsilon 0.6128 | Loss 0.093863
# Episode  224 | Reward   139.00 | Avg100    33.89 | Length  139 | Epsilon 0.6038 | Loss 0.124727
# Episode  225 | Reward   135.00 | Avg100    35.10 | Length  135 | Epsilon 0.5949 | Loss 0.115033
# Episode  226 | Reward    22.00 | Avg100    35.16 | Length   22 | Epsilon 0.5935 | Loss 0.124655
# Episode  227 | Reward    37.00 | Avg100    35.39 | Length   37 | Epsilon 0.5911 | Loss 0.114627
# Episode  228 | Reward   137.00 | Avg100    36.52 | Length  137 | Epsilon 0.5821 | Loss 0.114733
# Episode  229 | Reward    42.00 | Avg100    36.59 | Length   42 | Epsilon 0.5794 | Loss 0.105627
# Episode  230 | Reward   127.00 | Avg100    37.74 | Length  127 | Epsilon 0.5711 | Loss 0.102612
# Episode  231 | Reward    27.00 | Avg100    37.84 | Length   27 | Epsilon 0.5693 | Loss 0.101776
# Episode  232 | Reward   139.00 | Avg100    38.92 | Length  139 | Epsilon 0.5602 | Loss 0.109606
# Episode  233 | Reward    72.00 | Avg100    39.33 | Length   72 | Epsilon 0.5555 | Loss 0.103583
# Episode  234 | Reward    82.00 | Avg100    40.01 | Length   82 | Epsilon 0.5502 | Loss 0.104238
# Episode  235 | Reward    59.00 | Avg100    40.37 | Length   59 | Epsilon 0.5463 | Loss 0.075918
# Episode  236 | Reward   166.00 | Avg100    41.86 | Length  166 | Epsilon 0.5355 | Loss 0.139915
# Episode  237 | Reward    28.00 | Avg100    41.99 | Length   28 | Epsilon 0.5337 | Loss 0.107639
# Episode  238 | Reward    85.00 | Avg100    42.70 | Length   85 | Epsilon 0.5281 | Loss 0.130381
# Episode  239 | Reward    64.00 | Avg100    43.19 | Length   64 | Epsilon 0.5239 | Loss 0.112366
# Episode  240 | Reward   151.00 | Avg100    44.58 | Length  151 | Epsilon 0.5141 | Loss 0.125824
# Episode  241 | Reward   169.00 | Avg100    46.10 | Length  169 | Epsilon 0.5030 | Loss 0.133651
# Episode  242 | Reward   172.00 | Avg100    47.50 | Length  172 | Epsilon 0.4918 | Loss 0.117131
# Episode  243 | Reward   159.00 | Avg100    48.97 | Length  159 | Epsilon 0.4814 | Loss 0.108323
# Episode  244 | Reward   149.00 | Avg100    50.32 | Length  149 | Epsilon 0.4716 | Loss 0.152138
# Episode  245 | Reward   249.00 | Avg100    52.70 | Length  249 | Epsilon 0.4554 | Loss 0.126941
# Episode  246 | Reward    43.00 | Avg100    52.81 | Length   43 | Epsilon 0.4526 | Loss 0.125293
# Episode  247 | Reward   188.00 | Avg100    54.51 | Length  188 | Epsilon 0.4403 | Loss 0.139660
# Episode  248 | Reward    86.00 | Avg100    55.18 | Length   86 | Epsilon 0.4347 | Loss 0.136674
# Episode  249 | Reward   186.00 | Avg100    56.91 | Length  186 | Epsilon 0.4225 | Loss 0.125179
# Episode  250 | Reward    87.00 | Avg100    57.68 | Length   87 | Epsilon 0.4168 | Loss 0.120982
# Episode  251 | Reward    55.00 | Avg100    58.08 | Length   55 | Epsilon 0.4132 | Loss 0.124365
# Episode  252 | Reward   178.00 | Avg100    59.64 | Length  178 | Epsilon 0.4016 | Loss 0.169309
# Episode  253 | Reward   148.00 | Avg100    60.77 | Length  148 | Epsilon 0.3919 | Loss 0.133268
# Episode  254 | Reward   185.00 | Avg100    62.48 | Length  185 | Epsilon 0.3799 | Loss 0.137939
# Episode  255 | Reward   155.00 | Avg100    63.87 | Length  155 | Epsilon 0.3697 | Loss 0.130330
# Episode  256 | Reward   305.00 | Avg100    66.77 | Length  305 | Epsilon 0.3498 | Loss 0.132326
# Episode  257 | Reward   210.00 | Avg100    68.57 | Length  210 | Epsilon 0.3361 | Loss 0.175244
# Episode  258 | Reward   256.00 | Avg100    70.73 | Length  256 | Epsilon 0.3194 | Loss 0.150430
# Episode  259 | Reward   203.00 | Avg100    72.58 | Length  203 | Epsilon 0.3061 | Loss 0.140163
# Episode  260 | Reward   387.00 | Avg100    76.26 | Length  387 | Epsilon 0.2808 | Loss 0.150062
# Episode  261 | Reward   222.00 | Avg100    78.32 | Length  222 | Epsilon 0.2663 | Loss 0.163102
# Episode  262 | Reward   222.00 | Avg100    80.33 | Length  222 | Epsilon 0.2518 | Loss 0.159068
# Episode  263 | Reward   271.00 | Avg100    82.67 | Length  271 | Epsilon 0.2341 | Loss 0.161541
# Episode  264 | Reward   175.00 | Avg100    84.18 | Length  175 | Epsilon 0.2227 | Loss 0.153454
# Episode  265 | Reward   253.00 | Avg100    86.39 | Length  253 | Epsilon 0.2061 | Loss 0.165070
# Episode  266 | Reward   282.00 | Avg100    89.09 | Length  282 | Epsilon 0.1877 | Loss 0.161002
# Episode  267 | Reward   244.00 | Avg100    91.32 | Length  244 | Epsilon 0.1718 | Loss 0.153724
# Episode  268 | Reward   275.00 | Avg100    93.92 | Length  275 | Epsilon 0.1538 | Loss 0.161941
# Episode  269 | Reward   221.00 | Avg100    95.98 | Length  221 | Epsilon 0.1394 | Loss 0.193233
# Episode  270 | Reward   251.00 | Avg100    98.32 | Length  251 | Epsilon 0.1230 | Loss 0.145617
# Episode  271 | Reward   295.00 | Avg100   100.91 | Length  295 | Epsilon 0.1037 | Loss 0.161460
# Episode  272 | Reward   195.00 | Avg100   102.19 | Length  195 | Epsilon 0.0910 | Loss 0.149044
# Episode  273 | Reward   299.00 | Avg100   104.85 | Length  299 | Epsilon 0.0714 | Loss 0.191762
# Episode  274 | Reward   177.00 | Avg100   106.13 | Length  177 | Epsilon 0.0599 | Loss 0.191085
# Episode  275 | Reward   151.00 | Avg100   107.43 | Length  151 | Epsilon 0.0500 | Loss 0.172818
# Episode  276 | Reward   171.00 | Avg100   108.91 | Length  171 | Epsilon 0.0388 | Loss 0.174566
# Episode  277 | Reward   217.00 | Avg100   110.91 | Length  217 | Epsilon 0.0246 | Loss 0.177620
# Episode  278 | Reward   265.00 | Avg100   113.39 | Length  265 | Epsilon 0.0200 | Loss 0.210619
# Episode  279 | Reward   368.00 | Avg100   116.81 | Length  368 | Epsilon 0.0200 | Loss 0.176046
# Episode  280 | Reward   210.00 | Avg100   118.73 | Length  210 | Epsilon 0.0200 | Loss 0.187246
# Episode  281 | Reward   346.00 | Avg100   121.58 | Length  346 | Epsilon 0.0200 | Loss 0.199698
# Episode  282 | Reward   218.00 | Avg100   123.54 | Length  218 | Epsilon 0.0200 | Loss 0.191590
# Episode  283 | Reward   251.00 | Avg100   125.44 | Length  251 | Epsilon 0.0200 | Loss 0.193073
# Episode  284 | Reward   232.00 | Avg100   127.07 | Length  232 | Epsilon 0.0200 | Loss 0.169943
# Episode  285 | Reward   244.00 | Avg100   129.39 | Length  244 | Epsilon 0.0200 | Loss 0.196984
# Episode  286 | Reward   162.00 | Avg100   130.53 | Length  162 | Epsilon 0.0200 | Loss 0.167231
# Episode  287 | Reward   211.00 | Avg100   132.47 | Length  211 | Epsilon 0.0200 | Loss 0.201853
# Episode  288 | Reward   149.00 | Avg100   133.68 | Length  149 | Epsilon 0.0200 | Loss 0.186110
# Episode  289 | Reward   212.00 | Avg100   135.55 | Length  212 | Epsilon 0.0200 | Loss 0.195147
# Episode  290 | Reward   206.00 | Avg100   137.43 | Length  206 | Epsilon 0.0200 | Loss 0.194338
# Episode  291 | Reward   157.00 | Avg100   138.71 | Length  157 | Epsilon 0.0200 | Loss 0.210896
# Episode  292 | Reward   208.00 | Avg100   140.47 | Length  208 | Epsilon 0.0200 | Loss 0.188492
# Episode  293 | Reward   221.00 | Avg100   142.56 | Length  221 | Epsilon 0.0200 | Loss 0.202391
# Episode  294 | Reward   150.00 | Avg100   143.35 | Length  150 | Epsilon 0.0200 | Loss 0.199597
# Episode  295 | Reward   229.00 | Avg100   144.76 | Length  229 | Epsilon 0.0200 | Loss 0.204770
# Episode  296 | Reward   203.00 | Avg100   146.37 | Length  203 | Epsilon 0.0200 | Loss 0.214911
# Episode  297 | Reward   275.00 | Avg100   148.74 | Length  275 | Epsilon 0.0200 | Loss 0.230010
# Episode  298 | Reward   172.00 | Avg100   150.32 | Length  172 | Epsilon 0.0200 | Loss 0.200291
# Episode  299 | Reward   313.00 | Avg100   153.27 | Length  313 | Epsilon 0.0200 | Loss 0.190524
# Episode  300 | Reward   224.00 | Avg100   154.89 | Length  224 | Epsilon 0.0200 | Loss 0.216694
# Episode  301 | Reward   239.00 | Avg100   156.87 | Length  239 | Epsilon 0.0200 | Loss 0.191129
# Episode  302 | Reward   181.00 | Avg100   158.15 | Length  181 | Epsilon 0.0200 | Loss 0.197506
# Episode  303 | Reward   243.00 | Avg100   159.53 | Length  243 | Epsilon 0.0200 | Loss 0.196909
# Episode  304 | Reward   197.00 | Avg100   161.30 | Length  197 | Epsilon 0.0200 | Loss 0.207078
# Episode  305 | Reward   257.00 | Avg100   163.40 | Length  257 | Epsilon 0.0200 | Loss 0.207929
# Episode  306 | Reward   230.00 | Avg100   165.46 | Length  230 | Epsilon 0.0200 | Loss 0.214691
# Episode  307 | Reward   347.00 | Avg100   168.33 | Length  347 | Epsilon 0.0200 | Loss 0.206227
# Episode  308 | Reward   179.00 | Avg100   169.91 | Length  179 | Epsilon 0.0200 | Loss 0.220236
# Episode  309 | Reward   223.00 | Avg100   171.77 | Length  223 | Epsilon 0.0200 | Loss 0.194833
# Episode  310 | Reward   255.00 | Avg100   172.87 | Length  255 | Epsilon 0.0200 | Loss 0.210456
# Episode  311 | Reward   216.00 | Avg100   174.83 | Length  216 | Epsilon 0.0200 | Loss 0.215201
# Episode  312 | Reward   234.00 | Avg100   176.43 | Length  234 | Epsilon 0.0200 | Loss 0.216054
# Episode  313 | Reward   231.00 | Avg100   178.42 | Length  231 | Epsilon 0.0200 | Loss 0.214151
# Episode  314 | Reward   209.00 | Avg100   179.94 | Length  209 | Epsilon 0.0200 | Loss 0.223945
# Episode  315 | Reward   196.00 | Avg100   181.15 | Length  196 | Epsilon 0.0200 | Loss 0.224757
# Episode  316 | Reward   227.00 | Avg100   182.56 | Length  227 | Epsilon 0.0200 | Loss 0.207937
# Episode  317 | Reward   228.00 | Avg100   184.49 | Length  228 | Epsilon 0.0200 | Loss 0.225568
# Episode  318 | Reward   145.00 | Avg100   185.74 | Length  145 | Epsilon 0.0200 | Loss 0.219146
# Episode  319 | Reward   187.00 | Avg100   186.71 | Length  187 | Epsilon 0.0200 | Loss 0.204062
# Episode  320 | Reward   175.00 | Avg100   187.74 | Length  175 | Epsilon 0.0200 | Loss 0.226832
# Episode  321 | Reward   185.00 | Avg100   189.38 | Length  185 | Epsilon 0.0200 | Loss 0.233512
# Episode  322 | Reward   172.00 | Avg100   190.13 | Length  172 | Epsilon 0.0200 | Loss 0.230615
# Episode  323 | Reward   335.00 | Avg100   193.20 | Length  335 | Epsilon 0.0200 | Loss 0.217543
# Episode  324 | Reward   176.00 | Avg100   193.57 | Length  176 | Epsilon 0.0200 | Loss 0.217605
# Episode  325 | Reward   251.00 | Avg100   194.73 | Length  251 | Epsilon 0.0200 | Loss 0.224258
# Episode  326 | Reward   207.00 | Avg100   196.58 | Length  207 | Epsilon 0.0200 | Loss 0.212110
# Episode  327 | Reward   238.00 | Avg100   198.59 | Length  238 | Epsilon 0.0200 | Loss 0.226869
# Episode  328 | Reward   228.00 | Avg100   199.50 | Length  228 | Epsilon 0.0200 | Loss 0.193957
# Episode  329 | Reward   196.00 | Avg100   201.04 | Length  196 | Epsilon 0.0200 | Loss 0.224022
# Episode  330 | Reward   209.00 | Avg100   201.86 | Length  209 | Epsilon 0.0200 | Loss 0.242567
# Episode  331 | Reward   200.00 | Avg100   203.59 | Length  200 | Epsilon 0.0200 | Loss 0.231916
# Episode  332 | Reward   175.00 | Avg100   203.95 | Length  175 | Epsilon 0.0200 | Loss 0.245699
# Episode  333 | Reward   260.00 | Avg100   205.83 | Length  260 | Epsilon 0.0200 | Loss 0.233131
# Episode  334 | Reward   177.00 | Avg100   206.78 | Length  177 | Epsilon 0.0200 | Loss 0.202756
# Episode  335 | Reward   169.00 | Avg100   207.88 | Length  169 | Epsilon 0.0200 | Loss 0.243998
# Episode  336 | Reward   177.00 | Avg100   207.99 | Length  177 | Epsilon 0.0200 | Loss 0.213291
# Episode  337 | Reward   180.00 | Avg100   209.51 | Length  180 | Epsilon 0.0200 | Loss 0.203949
# Episode  338 | Reward   173.00 | Avg100   210.39 | Length  173 | Epsilon 0.0200 | Loss 0.251960
# Episode  339 | Reward   221.00 | Avg100   211.96 | Length  221 | Epsilon 0.0200 | Loss 0.235249
# Episode  340 | Reward   195.00 | Avg100   212.40 | Length  195 | Epsilon 0.0200 | Loss 0.250909
# Episode  341 | Reward   185.00 | Avg100   212.56 | Length  185 | Epsilon 0.0200 | Loss 0.248715
# Episode  342 | Reward   204.00 | Avg100   212.88 | Length  204 | Epsilon 0.0200 | Loss 0.253597
# Episode  343 | Reward   167.00 | Avg100   212.96 | Length  167 | Epsilon 0.0200 | Loss 0.217831
# Episode  344 | Reward   184.00 | Avg100   213.31 | Length  184 | Epsilon 0.0200 | Loss 0.244680
# Episode  345 | Reward   172.00 | Avg100   212.54 | Length  172 | Epsilon 0.0200 | Loss 0.236794
# Episode  346 | Reward   171.00 | Avg100   213.82 | Length  171 | Epsilon 0.0200 | Loss 0.244635
# Episode  347 | Reward   159.00 | Avg100   213.53 | Length  159 | Epsilon 0.0200 | Loss 0.220471
# Episode  348 | Reward   206.00 | Avg100   214.73 | Length  206 | Epsilon 0.0200 | Loss 0.250651
# Episode  349 | Reward   154.00 | Avg100   214.41 | Length  154 | Epsilon 0.0200 | Loss 0.208134
# Episode  350 | Reward   174.00 | Avg100   215.28 | Length  174 | Epsilon 0.0200 | Loss 0.248914
# Episode  351 | Reward   175.00 | Avg100   216.48 | Length  175 | Epsilon 0.0200 | Loss 0.245155
# Episode  352 | Reward   182.00 | Avg100   216.52 | Length  182 | Epsilon 0.0200 | Loss 0.251843
# Episode  353 | Reward   178.00 | Avg100   216.82 | Length  178 | Epsilon 0.0200 | Loss 0.274072
# Episode  354 | Reward   167.00 | Avg100   216.64 | Length  167 | Epsilon 0.0200 | Loss 0.238773
# Episode  355 | Reward   168.00 | Avg100   216.77 | Length  168 | Epsilon 0.0200 | Loss 0.236048
# Episode  356 | Reward   175.00 | Avg100   215.47 | Length  175 | Epsilon 0.0200 | Loss 0.245574
# Episode  357 | Reward   180.00 | Avg100   215.17 | Length  180 | Epsilon 0.0200 | Loss 0.196538
# Episode  358 | Reward   177.00 | Avg100   214.38 | Length  177 | Epsilon 0.0200 | Loss 0.205235
# Episode  359 | Reward   163.00 | Avg100   213.98 | Length  163 | Epsilon 0.0200 | Loss 0.270880
# Episode  360 | Reward   160.00 | Avg100   211.71 | Length  160 | Epsilon 0.0200 | Loss 0.200444
# Episode  361 | Reward   165.00 | Avg100   211.14 | Length  165 | Epsilon 0.0200 | Loss 0.236701
# Episode  362 | Reward   165.00 | Avg100   210.57 | Length  165 | Epsilon 0.0200 | Loss 0.254013
# Episode  363 | Reward   197.00 | Avg100   209.83 | Length  197 | Epsilon 0.0200 | Loss 0.242582
# Episode  364 | Reward   173.00 | Avg100   209.81 | Length  173 | Epsilon 0.0200 | Loss 0.249856
# Episode  365 | Reward   178.00 | Avg100   209.06 | Length  178 | Epsilon 0.0200 | Loss 0.266306
# Episode  366 | Reward   165.00 | Avg100   207.89 | Length  165 | Epsilon 0.0200 | Loss 0.237559
# Episode  367 | Reward   157.00 | Avg100   207.02 | Length  157 | Epsilon 0.0200 | Loss 0.232878
# Episode  368 | Reward   189.00 | Avg100   206.16 | Length  189 | Epsilon 0.0200 | Loss 0.233647
# Episode  369 | Reward   192.00 | Avg100   205.87 | Length  192 | Epsilon 0.0200 | Loss 0.247892
# Episode  370 | Reward   172.00 | Avg100   205.08 | Length  172 | Epsilon 0.0200 | Loss 0.241656
# Episode  371 | Reward   154.00 | Avg100   203.67 | Length  154 | Epsilon 0.0200 | Loss 0.240307
# Episode  372 | Reward   181.00 | Avg100   203.53 | Length  181 | Epsilon 0.0200 | Loss 0.247539
# Episode  373 | Reward   218.00 | Avg100   202.72 | Length  218 | Epsilon 0.0200 | Loss 0.253465
# Episode  374 | Reward   162.00 | Avg100   202.57 | Length  162 | Epsilon 0.0200 | Loss 0.226237
# Episode  375 | Reward   222.00 | Avg100   203.28 | Length  222 | Epsilon 0.0200 | Loss 0.234705
# Episode  376 | Reward   174.00 | Avg100   203.31 | Length  174 | Epsilon 0.0200 | Loss 0.254439
# Episode  377 | Reward   211.00 | Avg100   203.25 | Length  211 | Epsilon 0.0200 | Loss 0.251428
# Episode  378 | Reward   238.00 | Avg100   202.98 | Length  238 | Epsilon 0.0200 | Loss 0.258225
# Episode  379 | Reward   170.00 | Avg100   201.00 | Length  170 | Epsilon 0.0200 | Loss 0.238766
# Episode  380 | Reward   193.00 | Avg100   200.83 | Length  193 | Epsilon 0.0200 | Loss 0.268280
# Episode  381 | Reward   210.00 | Avg100   199.47 | Length  210 | Epsilon 0.0200 | Loss 0.288212
# Episode  382 | Reward   180.00 | Avg100   199.09 | Length  180 | Epsilon 0.0200 | Loss 0.290278
# Episode  383 | Reward   155.00 | Avg100   198.13 | Length  155 | Epsilon 0.0200 | Loss 0.270493
# Episode  384 | Reward   164.00 | Avg100   197.45 | Length  164 | Epsilon 0.0200 | Loss 0.243804
# Episode  385 | Reward   200.00 | Avg100   197.01 | Length  200 | Epsilon 0.0200 | Loss 0.306647
# Episode  386 | Reward   188.00 | Avg100   197.27 | Length  188 | Epsilon 0.0200 | Loss 0.258483
# Episode  387 | Reward   189.00 | Avg100   197.05 | Length  189 | Epsilon 0.0200 | Loss 0.270787
# Episode  388 | Reward   227.00 | Avg100   197.83 | Length  227 | Epsilon 0.0200 | Loss 0.239629
# Episode  389 | Reward   176.00 | Avg100   197.47 | Length  176 | Epsilon 0.0200 | Loss 0.292965
# Episode  390 | Reward   178.00 | Avg100   197.19 | Length  178 | Epsilon 0.0200 | Loss 0.242041
# Episode  391 | Reward   174.00 | Avg100   197.36 | Length  174 | Epsilon 0.0200 | Loss 0.266782
# Episode  392 | Reward   165.00 | Avg100   196.93 | Length  165 | Epsilon 0.0200 | Loss 0.315121
# Episode  393 | Reward   186.00 | Avg100   196.58 | Length  186 | Epsilon 0.0200 | Loss 0.250851
# Episode  394 | Reward   168.00 | Avg100   196.76 | Length  168 | Epsilon 0.0200 | Loss 0.268533
# Episode  395 | Reward   177.00 | Avg100   196.24 | Length  177 | Epsilon 0.0200 | Loss 0.272347
# Episode  396 | Reward   227.00 | Avg100   196.48 | Length  227 | Epsilon 0.0200 | Loss 0.250008
# Episode  397 | Reward   271.00 | Avg100   196.44 | Length  271 | Epsilon 0.0200 | Loss 0.259283
# Episode  398 | Reward   212.00 | Avg100   196.84 | Length  212 | Epsilon 0.0200 | Loss 0.244427
# Episode  399 | Reward   185.00 | Avg100   195.56 | Length  185 | Epsilon 0.0200 | Loss 0.294192
# Episode  400 | Reward   178.00 | Avg100   195.10 | Length  178 | Epsilon 0.0200 | Loss 0.280548
# Episode  401 | Reward   179.00 | Avg100   194.50 | Length  179 | Epsilon 0.0200 | Loss 0.250227
# Episode  402 | Reward   211.00 | Avg100   194.80 | Length  211 | Epsilon 0.0200 | Loss 0.307015
# Episode  403 | Reward   183.00 | Avg100   194.20 | Length  183 | Epsilon 0.0200 | Loss 0.331504
# Episode  404 | Reward   187.00 | Avg100   194.10 | Length  187 | Epsilon 0.0200 | Loss 0.303009
# Episode  405 | Reward   184.00 | Avg100   193.37 | Length  184 | Epsilon 0.0200 | Loss 0.251945
# Episode  406 | Reward   162.00 | Avg100   192.69 | Length  162 | Epsilon 0.0200 | Loss 0.256680
# Episode  407 | Reward   204.00 | Avg100   191.26 | Length  204 | Epsilon 0.0200 | Loss 0.261541
# Episode  408 | Reward   195.00 | Avg100   191.42 | Length  195 | Epsilon 0.0200 | Loss 0.274242
# Episode  409 | Reward   190.00 | Avg100   191.09 | Length  190 | Epsilon 0.0200 | Loss 0.269842
# Episode  410 | Reward   190.00 | Avg100   190.44 | Length  190 | Epsilon 0.0200 | Loss 0.249358
# Episode  411 | Reward   176.00 | Avg100   190.04 | Length  176 | Epsilon 0.0200 | Loss 0.242774
# Episode  412 | Reward   162.00 | Avg100   189.32 | Length  162 | Epsilon 0.0200 | Loss 0.311864
# Episode  413 | Reward   176.00 | Avg100   188.77 | Length  176 | Epsilon 0.0200 | Loss 0.258074
# Episode  414 | Reward   169.00 | Avg100   188.37 | Length  169 | Epsilon 0.0200 | Loss 0.283776
# Episode  415 | Reward   169.00 | Avg100   188.10 | Length  169 | Epsilon 0.0200 | Loss 0.265605
# Episode  416 | Reward   171.00 | Avg100   187.54 | Length  171 | Epsilon 0.0200 | Loss 0.283827
# Episode  417 | Reward   176.00 | Avg100   187.02 | Length  176 | Epsilon 0.0200 | Loss 0.272068
# Episode  418 | Reward   177.00 | Avg100   187.34 | Length  177 | Epsilon 0.0200 | Loss 0.209102
# Episode  419 | Reward   175.00 | Avg100   187.22 | Length  175 | Epsilon 0.0200 | Loss 0.231606
# Episode  420 | Reward   197.00 | Avg100   187.44 | Length  197 | Epsilon 0.0200 | Loss 0.267974
# Episode  421 | Reward   184.00 | Avg100   187.43 | Length  184 | Epsilon 0.0200 | Loss 0.267990
# Episode  422 | Reward   197.00 | Avg100   187.68 | Length  197 | Epsilon 0.0200 | Loss 0.250946
# Episode  423 | Reward   194.00 | Avg100   186.27 | Length  194 | Epsilon 0.0200 | Loss 0.291988
# Episode  424 | Reward   168.00 | Avg100   186.19 | Length  168 | Epsilon 0.0200 | Loss 0.260826
# Episode  425 | Reward   191.00 | Avg100   185.59 | Length  191 | Epsilon 0.0200 | Loss 0.268201
# Episode  426 | Reward   186.00 | Avg100   185.38 | Length  186 | Epsilon 0.0200 | Loss 0.279781
# Episode  427 | Reward   172.00 | Avg100   184.72 | Length  172 | Epsilon 0.0200 | Loss 0.282843
# Episode  428 | Reward   161.00 | Avg100   184.05 | Length  161 | Epsilon 0.0200 | Loss 0.279472
# Episode  429 | Reward   161.00 | Avg100   183.70 | Length  161 | Epsilon 0.0200 | Loss 0.240644
# Episode  430 | Reward   186.00 | Avg100   183.47 | Length  186 | Epsilon 0.0200 | Loss 0.299087
# Episode  431 | Reward   184.00 | Avg100   183.31 | Length  184 | Epsilon 0.0200 | Loss 0.314593
# Episode  432 | Reward   205.00 | Avg100   183.61 | Length  205 | Epsilon 0.0200 | Loss 0.293883
# Episode  433 | Reward   164.00 | Avg100   182.65 | Length  164 | Epsilon 0.0200 | Loss 0.246225
# Episode  434 | Reward   185.00 | Avg100   182.73 | Length  185 | Epsilon 0.0200 | Loss 0.271723
# Episode  435 | Reward   210.00 | Avg100   183.14 | Length  210 | Epsilon 0.0200 | Loss 0.291697
# Episode  436 | Reward   173.00 | Avg100   183.10 | Length  173 | Epsilon 0.0200 | Loss 0.243924
# Episode  437 | Reward   172.00 | Avg100   183.02 | Length  172 | Epsilon 0.0200 | Loss 0.252193
# Episode  438 | Reward   192.00 | Avg100   183.21 | Length  192 | Epsilon 0.0200 | Loss 0.329613
# Episode  439 | Reward   193.00 | Avg100   182.93 | Length  193 | Epsilon 0.0200 | Loss 0.253239
# Episode  440 | Reward   204.00 | Avg100   183.02 | Length  204 | Epsilon 0.0200 | Loss 0.300313
# Episode  441 | Reward   166.00 | Avg100   182.83 | Length  166 | Epsilon 0.0200 | Loss 0.301050
# Episode  442 | Reward   185.00 | Avg100   182.64 | Length  185 | Epsilon 0.0200 | Loss 0.297175
# Episode  443 | Reward   190.00 | Avg100   182.87 | Length  190 | Epsilon 0.0200 | Loss 0.278362
# Episode  444 | Reward   194.00 | Avg100   182.97 | Length  194 | Epsilon 0.0200 | Loss 0.248589
# Episode  445 | Reward   206.00 | Avg100   183.31 | Length  206 | Epsilon 0.0200 | Loss 0.280374
# Episode  446 | Reward   178.00 | Avg100   183.38 | Length  178 | Epsilon 0.0200 | Loss 0.302722
# Episode  447 | Reward   197.00 | Avg100   183.76 | Length  197 | Epsilon 0.0200 | Loss 0.281896
# Episode  448 | Reward   183.00 | Avg100   183.53 | Length  183 | Epsilon 0.0200 | Loss 0.305114
# Episode  449 | Reward   188.00 | Avg100   183.87 | Length  188 | Epsilon 0.0200 | Loss 0.282070
# Episode  450 | Reward   185.00 | Avg100   183.98 | Length  185 | Epsilon 0.0200 | Loss 0.282558
# Episode  451 | Reward   193.00 | Avg100   184.16 | Length  193 | Epsilon 0.0200 | Loss 0.270953
# Episode  452 | Reward   235.00 | Avg100   184.69 | Length  235 | Epsilon 0.0200 | Loss 0.284064
# Episode  453 | Reward   192.00 | Avg100   184.83 | Length  192 | Epsilon 0.0200 | Loss 0.310622
# Episode  454 | Reward   195.00 | Avg100   185.11 | Length  195 | Epsilon 0.0200 | Loss 0.300391
# Episode  455 | Reward   190.00 | Avg100   185.33 | Length  190 | Epsilon 0.0200 | Loss 0.264350
# Episode  456 | Reward   181.00 | Avg100   185.39 | Length  181 | Epsilon 0.0200 | Loss 0.253211
# Episode  457 | Reward   190.00 | Avg100   185.49 | Length  190 | Epsilon 0.0200 | Loss 0.284824
# Episode  458 | Reward   200.00 | Avg100   185.72 | Length  200 | Epsilon 0.0200 | Loss 0.262585
# Episode  459 | Reward   202.00 | Avg100   186.11 | Length  202 | Epsilon 0.0200 | Loss 0.239943
# Episode  460 | Reward   181.00 | Avg100   186.32 | Length  181 | Epsilon 0.0200 | Loss 0.219977
# Episode  461 | Reward   191.00 | Avg100   186.58 | Length  191 | Epsilon 0.0200 | Loss 0.248670
# Episode  462 | Reward   170.00 | Avg100   186.63 | Length  170 | Epsilon 0.0200 | Loss 0.239305
# Episode  463 | Reward   195.00 | Avg100   186.61 | Length  195 | Epsilon 0.0200 | Loss 0.257137
# Episode  464 | Reward   173.00 | Avg100   186.61 | Length  173 | Epsilon 0.0200 | Loss 0.231107
# Episode  465 | Reward   182.00 | Avg100   186.65 | Length  182 | Epsilon 0.0200 | Loss 0.293744
# Episode  466 | Reward   207.00 | Avg100   187.07 | Length  207 | Epsilon 0.0200 | Loss 0.236151
# Episode  605 | Reward   191.00 | Avg100   190.63 | Length  191 | Epsilon 0.0200 | Loss 0.127342
# Episode  606 | Reward   203.00 | Avg100   190.80 | Length  203 | Epsilon 0.0200 | Loss 0.163392
# Episode  607 | Reward   276.00 | Avg100   191.94 | Length  276 | Epsilon 0.0200 | Loss 0.148138
# Episode  608 | Reward   179.00 | Avg100   191.68 | Length  179 | Epsilon 0.0200 | Loss 0.117713
# Episode  609 | Reward   217.00 | Avg100   191.86 | Length  217 | Epsilon 0.0200 | Loss 0.157608
# Episode  610 | Reward   190.00 | Avg100   192.01 | Length  190 | Epsilon 0.0200 | Loss 0.154686
# Episode  611 | Reward   181.00 | Avg100   191.83 | Length  181 | Epsilon 0.0200 | Loss 0.134773
# Episode  612 | Reward   196.00 | Avg100   191.85 | Length  196 | Epsilon 0.0200 | Loss 0.154902
# Episode  613 | Reward    29.00 | Avg100   190.47 | Length   29 | Epsilon 0.0200 | Loss 0.162585
# Episode  614 | Reward   197.00 | Avg100   190.67 | Length  197 | Epsilon 0.0200 | Loss 0.133972
# Episode  615 | Reward   155.00 | Avg100   190.35 | Length  155 | Epsilon 0.0200 | Loss 0.101204
# Episode  616 | Reward   170.00 | Avg100   190.18 | Length  170 | Epsilon 0.0200 | Loss 0.158624
# Episode  617 | Reward   163.00 | Avg100   189.21 | Length  163 | Epsilon 0.0200 | Loss 0.083411
# Episode  618 | Reward   189.00 | Avg100   189.33 | Length  189 | Epsilon 0.0200 | Loss 0.147857
# Episode  619 | Reward   185.00 | Avg100   189.22 | Length  185 | Epsilon 0.0200 | Loss 0.138977
# Episode  620 | Reward   164.00 | Avg100   188.96 | Length  164 | Epsilon 0.0200 | Loss 0.120862
# Episode  621 | Reward   172.00 | Avg100   188.84 | Length  172 | Epsilon 0.0200 | Loss 0.126855
# Episode  622 | Reward   188.00 | Avg100   188.74 | Length  188 | Epsilon 0.0200 | Loss 0.115389
# Episode  623 | Reward   164.00 | Avg100   188.37 | Length  164 | Epsilon 0.0200 | Loss 0.113870
# Episode  624 | Reward   184.00 | Avg100   188.24 | Length  184 | Epsilon 0.0200 | Loss 0.112007
# Episode  625 | Reward   182.00 | Avg100   188.16 | Length  182 | Epsilon 0.0200 | Loss 0.108276
# Episode  626 | Reward   190.00 | Avg100   188.16 | Length  190 | Epsilon 0.0200 | Loss 0.124036
# Episode  627 | Reward   165.00 | Avg100   187.90 | Length  165 | Epsilon 0.0200 | Loss 0.129444
# Episode  628 | Reward   167.00 | Avg100   187.86 | Length  167 | Epsilon 0.0200 | Loss 0.152027
# Episode  629 | Reward   184.00 | Avg100   187.88 | Length  184 | Epsilon 0.0200 | Loss 0.166019
# Episode  630 | Reward   167.00 | Avg100   187.60 | Length  167 | Epsilon 0.0200 | Loss 0.150340
# Episode  631 | Reward   171.00 | Avg100   187.49 | Length  171 | Epsilon 0.0200 | Loss 0.143739
# ...
# Episode 1844 | Reward   235.00 | Avg100   299.43 | Length  235 | Epsilon 0.0200 | Loss 0.206132
# Episode 1845 | Reward    78.00 | Avg100   298.10 | Length   78 | Epsilon 0.0200 | Loss 0.268910
# Episode 1846 | Reward    76.00 | Avg100   296.69 | Length   76 | Epsilon 0.0200 | Loss 0.207651
# Episode 1847 | Reward    11.00 | Avg100   294.73 | Length   11 | Epsilon 0.0200 | Loss 0.368469
# Episode 1848 | Reward    86.00 | Avg100   293.49 | Length   86 | Epsilon 0.0200 | Loss 0.309790
# Episode 1849 | Reward    96.00 | Avg100   292.39 | Length   96 | Epsilon 0.0200 | Loss 0.251809
# Episode 1850 | Reward   225.00 | Avg100   292.42 | Length  225 | Epsilon 0.0200 | Loss 0.194999
# Episode 1851 | Reward   214.00 | Avg100   292.24 | Length  214 | Epsilon 0.0200 | Loss 0.212979
# Episode 1852 | Reward   226.00 | Avg100   292.29 | Length  226 | Epsilon 0.0200 | Loss 0.221301
# Episode 1853 | Reward    95.00 | Avg100   291.03 | Length   95 | Epsilon 0.0200 | Loss 0.293869
# Episode 1854 | Reward   219.00 | Avg100   291.04 | Length  219 | Epsilon 0.0200 | Loss 0.248393
# Episode 1855 | Reward    91.00 | Avg100   289.78 | Length   91 | Epsilon 0.0200 | Loss 0.229707
# Episode 1856 | Reward    11.00 | Avg100   287.14 | Length   11 | Epsilon 0.0200 | Loss 0.366877
# Episode 1857 | Reward    12.00 | Avg100   282.26 | Length   12 | Epsilon 0.0200 | Loss 0.103476
# Episode 1858 | Reward    73.00 | Avg100   280.49 | Length   73 | Epsilon 0.0200 | Loss 0.319772
# Episode 1859 | Reward    52.00 | Avg100   280.88 | Length   52 | Epsilon 0.0200 | Loss 0.185891
# Episode 1860 | Reward    79.00 | Avg100   278.46 | Length   79 | Epsilon 0.0200 | Loss 0.270993
# Episode 1861 | Reward    71.00 | Avg100   276.38 | Length   71 | Epsilon 0.0200 | Loss 0.286816
# Episode 1862 | Reward    80.00 | Avg100   274.17 | Length   80 | Epsilon 0.0200 | Loss 0.318147
# Episode 1863 | Reward    82.00 | Avg100   272.44 | Length   82 | Epsilon 0.0200 | Loss 0.194927
# Episode 1864 | Reward   146.00 | Avg100   271.44 | Length  146 | Epsilon 0.0200 | Loss 0.229510
# Episode 1865 | Reward    72.00 | Avg100   269.64 | Length   72 | Epsilon 0.0200 | Loss 0.236011
# Episode 1866 | Reward    67.00 | Avg100   267.84 | Length   67 | Epsilon 0.0200 | Loss 0.344677
# Episode 1867 | Reward    62.00 | Avg100   266.08 | Length   62 | Epsilon 0.0200 | Loss 0.275058
# Episode 1868 | Reward    73.00 | Avg100   264.36 | Length   73 | Epsilon 0.0200 | Loss 0.266960
# Episode 1869 | Reward    74.00 | Avg100   262.73 | Length   74 | Epsilon 0.0200 | Loss 0.157690
# Episode 1870 | Reward    75.00 | Avg100   260.95 | Length   75 | Epsilon 0.0200 | Loss 0.271840
# Episode 1871 | Reward   242.00 | Avg100   260.84 | Length  242 | Epsilon 0.0200 | Loss 0.253056
# Episode 1872 | Reward    80.00 | Avg100   259.01 | Length   80 | Epsilon 0.0200 | Loss 0.211668
# Episode 1873 | Reward    76.00 | Avg100   257.05 | Length   76 | Epsilon 0.0200 | Loss 0.145565
# Episode 1874 | Reward    64.00 | Avg100   255.09 | Length   64 | Epsilon 0.0200 | Loss 0.271601
# Episode 1875 | Reward    83.00 | Avg100   250.92 | Length   83 | Epsilon 0.0200 | Loss 0.288022
# Episode 1876 | Reward    93.00 | Avg100   247.73 | Length   93 | Epsilon 0.0200 | Loss 0.348044
# Episode 1877 | Reward   221.00 | Avg100   246.90 | Length  221 | Epsilon 0.0200 | Loss 0.205991
# Episode 1878 | Reward    74.00 | Avg100   244.78 | Length   74 | Epsilon 0.0200 | Loss 0.328333
# Episode 1879 | Reward    98.00 | Avg100   242.80 | Length   98 | Epsilon 0.0200 | Loss 0.197216
# Episode 1880 | Reward    80.00 | Avg100   240.63 | Length   80 | Epsilon 0.0200 | Loss 0.235846
# Episode 1881 | Reward    64.00 | Avg100   238.36 | Length   64 | Epsilon 0.0200 | Loss 0.336174
# Episode 1882 | Reward    72.00 | Avg100   236.29 | Length   72 | Epsilon 0.0200 | Loss 0.364291
# Episode 1883 | Reward    69.00 | Avg100   234.20 | Length   69 | Epsilon 0.0200 | Loss 0.273132
# Episode 1884 | Reward    88.00 | Avg100   230.08 | Length   88 | Epsilon 0.0200 | Loss 0.242727
# Episode 1885 | Reward    58.00 | Avg100   225.66 | Length   58 | Epsilon 0.0200 | Loss 0.289733
# Episode 1886 | Reward    69.00 | Avg100   221.35 | Length   69 | Epsilon 0.0200 | Loss 0.297185
# Episode 1887 | Reward    76.00 | Avg100   217.11 | Length   76 | Epsilon 0.0200 | Loss 0.222001
# Episode 1888 | Reward    81.00 | Avg100   212.92 | Length   81 | Epsilon 0.0200 | Loss 0.184583
# Episode 1889 | Reward    70.00 | Avg100   208.62 | Length   70 | Epsilon 0.0200 | Loss 0.201088
# Episode 1890 | Reward   260.00 | Avg100   206.22 | Length  260 | Epsilon 0.0200 | Loss 0.304186
# Episode 1891 | Reward    75.00 | Avg100   201.97 | Length   75 | Epsilon 0.0200 | Loss 0.422424
# Episode 1892 | Reward   117.00 | Avg100   198.14 | Length  117 | Epsilon 0.0200 | Loss 0.399604
# Episode 1893 | Reward   243.00 | Avg100   195.57 | Length  243 | Epsilon 0.0200 | Loss 0.341652
# Episode 1894 | Reward   132.00 | Avg100   191.89 | Length  132 | Epsilon 0.0200 | Loss 0.349749
# Episode 1895 | Reward   285.00 | Avg100   189.74 | Length  285 | Epsilon 0.0200 | Loss 0.401282
# Episode 1896 | Reward   139.00 | Avg100   186.13 | Length  139 | Epsilon 0.0200 | Loss 0.309421
# Episode 1897 | Reward    70.00 | Avg100   184.63 | Length   70 | Epsilon 0.0200 | Loss 0.422409
# Episode 1898 | Reward    70.00 | Avg100   180.33 | Length   70 | Epsilon 0.0200 | Loss 0.413906
# Episode 1899 | Reward    83.00 | Avg100   177.50 | Length   83 | Epsilon 0.0200 | Loss 0.388314
# Episode 1900 | Reward   103.00 | Avg100   174.95 | Length  103 | Epsilon 0.0200 | Loss 0.249954
# Episode 1901 | Reward    96.00 | Avg100   175.74 | Length   96 | Epsilon 0.0200 | Loss 0.316866
# Episode 1902 | Reward   100.00 | Avg100   171.74 | Length  100 | Epsilon 0.0200 | Loss 0.167185
# Episode 1903 | Reward    71.00 | Avg100   167.45 | Length   71 | Epsilon 0.0200 | Loss 0.254222
# Episode 1904 | Reward    75.00 | Avg100   163.20 | Length   75 | Epsilon 0.0200 | Loss 0.366908
# Episode 1905 | Reward    83.00 | Avg100   159.03 | Length   83 | Epsilon 0.0200 | Loss 0.358424
# Episode 1906 | Reward    82.00 | Avg100   154.85 | Length   82 | Epsilon 0.0200 | Loss 0.323749
# Episode 1907 | Reward    67.00 | Avg100   154.87 | Length   67 | Epsilon 0.0200 | Loss 0.229549
# Episode 1908 | Reward    88.00 | Avg100   150.75 | Length   88 | Epsilon 0.0200 | Loss 0.260969
# Episode 1909 | Reward    80.00 | Avg100   146.55 | Length   80 | Epsilon 0.0200 | Loss 0.240699
# Episode 1910 | Reward    96.00 | Avg100   142.51 | Length   96 | Epsilon 0.0200 | Loss 0.386013
# Episode 1911 | Reward    82.00 | Avg100   138.33 | Length   82 | Epsilon 0.0200 | Loss 0.270032
# Episode 1912 | Reward    62.00 | Avg100   138.80 | Length   62 | Epsilon 0.0200 | Loss 0.531212
# Episode 1913 | Reward    90.00 | Avg100   136.28 | Length   90 | Epsilon 0.0200 | Loss 0.325992
# Episode 1914 | Reward    88.00 | Avg100   137.02 | Length   88 | Epsilon 0.0200 | Loss 0.338318
# Episode 1915 | Reward    80.00 | Avg100   137.69 | Length   80 | Epsilon 0.0200 | Loss 0.326396
# Episode 1916 | Reward    96.00 | Avg100   133.65 | Length   96 | Epsilon 0.0200 | Loss 0.155897
# Episode 1917 | Reward    85.00 | Avg100   129.50 | Length   85 | Epsilon 0.0200 | Loss 0.374251
# Episode 1918 | Reward    95.00 | Avg100   130.32 | Length   95 | Epsilon 0.0200 | Loss 0.366682
# Episode 1919 | Reward    90.00 | Avg100   131.06 | Length   90 | Epsilon 0.0200 | Loss 0.303513
# Episode 1920 | Reward   184.00 | Avg100   132.69 | Length  184 | Epsilon 0.0200 | Loss 0.378423
# Episode 1921 | Reward   319.00 | Avg100   135.76 | Length  319 | Epsilon 0.0200 | Loss 0.307856
# Episode 1922 | Reward   110.00 | Avg100   132.02 | Length  110 | Epsilon 0.0200 | Loss 0.371385
# Episode 1923 | Reward   122.00 | Avg100   130.24 | Length  122 | Epsilon 0.0200 | Loss 0.346705
# Episode 1924 | Reward   301.00 | Avg100   130.26 | Length  301 | Epsilon 0.0200 | Loss 0.354635
# Episode 1925 | Reward   111.00 | Avg100   128.47 | Length  111 | Epsilon 0.0200 | Loss 0.390867
# Episode 1926 | Reward   287.00 | Avg100   128.25 | Length  287 | Epsilon 0.0200 | Loss 0.345357
# Episode 1927 | Reward   152.00 | Avg100   124.77 | Length  152 | Epsilon 0.0200 | Loss 0.341856
# Episode 1928 | Reward   128.00 | Avg100   123.40 | Length  128 | Epsilon 0.0200 | Loss 0.420524
# Episode 1929 | Reward   123.00 | Avg100   121.68 | Length  123 | Epsilon 0.0200 | Loss 0.310037
# Episode 1930 | Reward   124.00 | Avg100   119.81 | Length  124 | Epsilon 0.0200 | Loss 0.316455
# Episode 1931 | Reward   453.00 | Avg100   121.96 | Length  453 | Epsilon 0.0200 | Loss 0.397861
# Episode 1932 | Reward   151.00 | Avg100   121.29 | Length  151 | Epsilon 0.0200 | Loss 0.451204
# Episode 1933 | Reward   390.00 | Avg100   122.78 | Length  390 | Epsilon 0.0200 | Loss 0.337162
# Episode 1934 | Reward   118.00 | Avg100   121.72 | Length  118 | Epsilon 0.0200 | Loss 0.383906
# Episode 1935 | Reward   500.00 | Avg100   126.61 | Length  500 | Epsilon 0.0200 | Loss 0.377304
# Episode 1936 | Reward   131.00 | Avg100   125.81 | Length  131 | Epsilon 0.0200 | Loss 0.336260
# Episode 1937 | Reward   123.00 | Avg100   126.92 | Length  123 | Epsilon 0.0200 | Loss 0.318471
# Episode 1938 | Reward   129.00 | Avg100   125.83 | Length  129 | Epsilon 0.0200 | Loss 0.371497
# Episode 1939 | Reward   120.00 | Avg100   124.70 | Length  120 | Epsilon 0.0200 | Loss 0.376068
# Episode 1940 | Reward   116.00 | Avg100   123.43 | Length  116 | Epsilon 0.0200 | Loss 0.300933
# Episode 1941 | Reward   132.00 | Avg100   122.34 | Length  132 | Epsilon 0.0200 | Loss 0.535382
# Episode 1942 | Reward   126.00 | Avg100   122.61 | Length  126 | Epsilon 0.0200 | Loss 0.298228
# Episode 1943 | Reward   133.00 | Avg100   122.05 | Length  133 | Epsilon 0.0200 | Loss 0.313788
# Episode 1944 | Reward   130.00 | Avg100   121.00 | Length  130 | Epsilon 0.0200 | Loss 0.479601
# Episode 1945 | Reward   129.00 | Avg100   121.51 | Length  129 | Epsilon 0.0200 | Loss 0.304451
# Episode 1946 | Reward   118.00 | Avg100   121.93 | Length  118 | Epsilon 0.0200 | Loss 0.449237
# Episode 1947 | Reward   136.00 | Avg100   123.18 | Length  136 | Epsilon 0.0200 | Loss 0.368267
# Episode 1948 | Reward   126.00 | Avg100   123.58 | Length  126 | Epsilon 0.0200 | Loss 0.365665
# Episode 1949 | Reward   116.00 | Avg100   123.78 | Length  116 | Epsilon 0.0200 | Loss 0.460184
# Episode 1950 | Reward   141.00 | Avg100   122.94 | Length  141 | Epsilon 0.0200 | Loss 0.421947
# Episode 1951 | Reward   130.00 | Avg100   122.10 | Length  130 | Epsilon 0.0200 | Loss 0.245494
# Episode 1952 | Reward   137.00 | Avg100   121.21 | Length  137 | Epsilon 0.0200 | Loss 0.348337
# Episode 1953 | Reward   128.00 | Avg100   121.54 | Length  128 | Epsilon 0.0200 | Loss 0.409582
# Episode 1954 | Reward   300.00 | Avg100   122.35 | Length  300 | Epsilon 0.0200 | Loss 0.408179
# Episode 1955 | Reward   128.00 | Avg100   122.72 | Length  128 | Epsilon 0.0200 | Loss 0.428962
# Episode 1956 | Reward   122.00 | Avg100   123.83 | Length  122 | Epsilon 0.0200 | Loss 0.336252
# Episode 1957 | Reward   456.00 | Avg100   128.27 | Length  456 | Epsilon 0.0200 | Loss 0.410840
# Episode 1958 | Reward   500.00 | Avg100   132.54 | Length  500 | Epsilon 0.0200 | Loss 0.409126
# Episode 1959 | Reward   500.00 | Avg100   137.02 | Length  500 | Epsilon 0.0200 | Loss 0.368753
# Episode 1960 | Reward   500.00 | Avg100   141.23 | Length  500 | Epsilon 0.0200 | Loss 0.394056
# Episode 1961 | Reward   500.00 | Avg100   145.52 | Length  500 | Epsilon 0.0200 | Loss 0.399954
# Episode 1962 | Reward   500.00 | Avg100   149.72 | Length  500 | Epsilon 0.0200 | Loss 0.415962
# Episode 1963 | Reward   500.00 | Avg100   153.90 | Length  500 | Epsilon 0.0200 | Loss 0.407751
# Episode 1964 | Reward   500.00 | Avg100   157.44 | Length  500 | Epsilon 0.0200 | Loss 0.343052
# Episode 1965 | Reward   500.00 | Avg100   161.72 | Length  500 | Epsilon 0.0200 | Loss 0.352587
# Episode 1966 | Reward   500.00 | Avg100   166.05 | Length  500 | Epsilon 0.0200 | Loss 0.340035
# Episode 1967 | Reward   500.00 | Avg100   170.43 | Length  500 | Epsilon 0.0200 | Loss 0.270566
# Episode 1968 | Reward   500.00 | Avg100   174.70 | Length  500 | Epsilon 0.0200 | Loss 0.336802
# Episode 1969 | Reward   500.00 | Avg100   178.96 | Length  500 | Epsilon 0.0200 | Loss 0.316391
# Episode 1970 | Reward   500.00 | Avg100   183.21 | Length  500 | Epsilon 0.0200 | Loss 0.311945
# Episode 1971 | Reward   500.00 | Avg100   185.79 | Length  500 | Epsilon 0.0200 | Loss 0.322351
# Episode 1972 | Reward   500.00 | Avg100   189.99 | Length  500 | Epsilon 0.0200 | Loss 0.305871
# Episode 1973 | Reward   500.00 | Avg100   194.23 | Length  500 | Epsilon 0.0200 | Loss 0.279088
# Episode 1974 | Reward   500.00 | Avg100   198.59 | Length  500 | Epsilon 0.0200 | Loss 0.301363
# Episode 1975 | Reward   500.00 | Avg100   202.76 | Length  500 | Epsilon 0.0200 | Loss 0.280050
# Episode 1976 | Reward   500.00 | Avg100   206.83 | Length  500 | Epsilon 0.0200 | Loss 0.285305
# Episode 1977 | Reward   500.00 | Avg100   209.62 | Length  500 | Epsilon 0.0200 | Loss 0.334645
# Episode 1978 | Reward   500.00 | Avg100   213.88 | Length  500 | Epsilon 0.0200 | Loss 0.316335
# Episode 1979 | Reward   500.00 | Avg100   217.90 | Length  500 | Epsilon 0.0200 | Loss 0.283650
# Episode 1980 | Reward   500.00 | Avg100   222.10 | Length  500 | Epsilon 0.0200 | Loss 0.255010
# Episode 1981 | Reward   500.00 | Avg100   226.46 | Length  500 | Epsilon 0.0200 | Loss 0.236042
# Episode 1982 | Reward   500.00 | Avg100   230.74 | Length  500 | Epsilon 0.0200 | Loss 0.292073
# Episode 1983 | Reward   500.00 | Avg100   235.05 | Length  500 | Epsilon 0.0200 | Loss 0.341054
# Episode 1984 | Reward   500.00 | Avg100   239.17 | Length  500 | Epsilon 0.0200 | Loss 0.287740
# Episode 1985 | Reward   500.00 | Avg100   243.59 | Length  500 | Epsilon 0.0200 | Loss 0.338126
# Episode 1986 | Reward   500.00 | Avg100   247.90 | Length  500 | Epsilon 0.0200 | Loss 0.263591
# Episode 1987 | Reward   500.00 | Avg100   252.14 | Length  500 | Epsilon 0.0200 | Loss 0.263542
# Episode 1988 | Reward   500.00 | Avg100   256.33 | Length  500 | Epsilon 0.0200 | Loss 0.285107
# Episode 1989 | Reward   500.00 | Avg100   260.63 | Length  500 | Epsilon 0.0200 | Loss 0.282016
# Episode 1990 | Reward   500.00 | Avg100   263.03 | Length  500 | Epsilon 0.0200 | Loss 0.297053
# Episode 1991 | Reward   500.00 | Avg100   267.28 | Length  500 | Epsilon 0.0200 | Loss 0.277246
# Episode 1992 | Reward   500.00 | Avg100   271.11 | Length  500 | Epsilon 0.0200 | Loss 0.266987
# Episode 1993 | Reward   500.00 | Avg100   273.68 | Length  500 | Epsilon 0.0200 | Loss 0.292853
# Episode 1994 | Reward   500.00 | Avg100   277.36 | Length  500 | Epsilon 0.0200 | Loss 0.272327
# Episode 1995 | Reward   500.00 | Avg100   279.51 | Length  500 | Epsilon 0.0200 | Loss 0.325839
# Episode 1996 | Reward   500.00 | Avg100   283.12 | Length  500 | Epsilon 0.0200 | Loss 0.286747
# Episode 1997 | Reward   500.00 | Avg100   287.42 | Length  500 | Epsilon 0.0200 | Loss 0.301470
# Episode 1998 | Reward   500.00 | Avg100   291.72 | Length  500 | Epsilon 0.0200 | Loss 0.281830
# Episode 1999 | Reward   500.00 | Avg100   295.89 | Length  500 | Epsilon 0.0200 | Loss 0.287131
# Episode 2000 | Reward   500.00 | Avg100   299.86 | Length  500 | Epsilon 0.0200 | Loss 0.250477
# Model saved: experiment_2_CartPole_v1_DoubleDQN.pth
#
# ======================================================================
# FINAL EVALUATION
# ======================================================================
# Experiment ID : 2
# Environment   : CartPole-v1
# Algorithm     : DoubleDQN
# Average Reward: 500.00
# Reward Std    : 0.00
# Average Length: 500.00
# Success Rate  : 100.00%
# ======================================================================
# Results saved: experiment_2_results.npz
# ======================================================================
# EXPERIMENT COMPLETE
# ======================================================================
# Experiment ID  : 2
# Environment    : CartPole-v1
# Algorithm      : DoubleDQN
# Average Reward : 500.00
# Reward Std     : 0.00
# Average Length : 500.00
# Success Rate   : 100.00%
# Best Train Avg : 500.00
# ======================================================================
